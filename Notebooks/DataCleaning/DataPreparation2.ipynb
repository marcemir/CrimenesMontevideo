# %% [markdown]
# #### DATASET DE CRÍMENES DENUNCIADOS EN URUGUAY
# #### FUENTE
# - https://catalogodatos.gub.uy/dataset/ministerio-del-interior-delitos_denunciados_en_el_uruguay
#
# #### DESCRIPCIÓN DE VARIABLES
#
# #### ID_EVENTO
# **Descripción**: IDENTIFICADOR ÚNICO DEL EVENTO
# **Información Adicional**: Esta variable es creada únicamente con objetivo de facilitar el procesamiento de los datos. A los efectos de anonimizar la información, no se corresponde con ninguna variable administrativa que identifique el evento.
# **Tipo de Dato**: String
#
# #### DELITO
# **Descripción**: TIPO DE DELITO
# **Información Adicional**: Indica el tipo de delito según la carátula con que está registrado en el Sistema de Gestión de Seguridad Pública. La categoría “LESIONES” incluye los delitos de Lesiones Personales (Artículo 316, CP), Lesiones Graves (Artículo 317, CP) y Lesiones Gravísimas (Artículo 318, CP).
# **Tipo de Dato**: String
#
# #### VICT_RAP
# **Descripción**: TIPO DE VÍCTIMA EN RAPIÑAS
# **Información Adicional**: Esta variable refiere a los tipos de víctimas para el delito de Rapiña, para los demás delitos asume la categoría de “NO CORRESPONDE”.
# **Tipo de Dato**: String
#
# #### VICT_HUR
# **Descripción**: TIPO DE VÍCTIMA EN HURTOS
# **Información Adicional**: Esta variable refiere a los tipos de víctimas para el delito de Hurto, para los demás delitos asume la categoría de “NO CORRESPONDE”.
# **Tipo de Dato**: String
#
# #### TENTATIVA
# **Descripción**: EVENTO TENTATIVO
# **Información Adicional**: La categoría “SI” indica eventos tentativos. La categoría “NO” indica eventos consumados.
# **Tipo de Dato**: String
#
# #### FECHA
# **Descripción**: FECHA DE OCURRENCIA DEL EVENTO
# **Información Adicional**:
# **Tipo de Dato**: Date
#
# #### AÑO
# **Descripción**: AÑO DE OCURRENCIA DEL EVENTO
# **Información Adicional**:
# **Tipo de Dato**: Numeric
#
# #### MES
# **Descripción**: MES DE OCURRENCIA DEL EVENTO
# **Información Adicional**:
# **Tipo de Dato**: String
#
# #### SEMESTRE
# **Descripción**: SEMESTRE DE OCURRENCIA DEL EVENTO
# **Información Adicional**:
# **Tipo de Dato**: String
#
# #### TRIMESTRE
# **Descripción**: TRIMESTRE DE OCURRENCIA DEL EVENTO
# **Información Adicional**:
# **Tipo de Dato**: String
#
# #### DIA_SEMANA
# **Descripción**: DÍA DE LA SEMANA DE OCURRENCIA DEL EVENTO
# **Información Adicional**:
# **Tipo de Dato**: String
#
# #### HORA
# **Descripción**: HORA DE OCURRENCIA DEL EVENTO
# **Información Adicional**: Los delitos de Hurto y Abigeato no suelen ocurrir en presencia de la víctima, esto dificulta la posibilidad de conocer con precisión la hora en que ocurre el evento delictivo. Por tal motivo, para estos delitos no se presentan datos en esta variable. Los casos de hurtos a transeúntes (arrebatos) constituyen una excepción, dado que la presencia de las víctimas está asegurada, para estos eventos se reporta la hora de ocurrencia.
# **Tipo de Dato**: String
#
# #### DEPTO
# **Descripción**: DEPARTAMENTO DONDE OCURRE EL EVENTO
# **Información Adicional**: Indica el Departamento donde ocurrió el evento delictivo tal como se registró al ingresar el caso en el Sistema de Gestión de Seguridad Pública.
# **Tipo de Dato**: String
#
# #### JURISDICCION
# **Descripción**: SECCIONAL POLICIAL DE JURISDICCIÓN DEL EVENTO
# **Información Adicional**: Indica la Jurisdicción Policial donde ocurrió el evento delictivo tal como se registró al ingresar el caso en el Sistema de Gestión de Seguridad Pública. Es importante tener en cuenta que los límites administrativos de las jurisdicciones policiales han cambiado durante el período, generándose incluso nuevas jurisdicciones. Por tal motivo, no es recomendable efectuar comparaciones interanuales con esta variable sin conocer dichas modificaciones.
# **Tipo de Dato**: String
#
# #### BARRIO_MONTEVIDEO
# **Descripción**: BARRIO DE MONTEVIDEO DONDE OCURRE EL EVENTO
# **Información Adicional**: Para los eventos delictivos ocurridos en el Departamento de Montevideo, indica el barrio donde sucedieron. Para los demás eventos asume la categoría de “NO CORRESPONDE”. Esta variable fue construida mediante georreferenciación, cruzando las coordenadas geográficas del evento con un shapefile de barrios elaborado por el Instituto Nacional de Estadísticas (https://www.gub.uy/instituto-nacional-estadistica/datos-y-estadisticas/estadisticas/mapas-vectoriales-ano-2011).
# **Tipo de Dato**: String

# %%
#Librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carga de datos usando link de google drive
'''
import gdown
file_id = "1E_JwOdHKmFVzZgOPa8xABGLAc37RsHbW"
destination = "otros-delitos.csv"  # Nombre del archivo local
gdown.download(f"https://drive.google.com/uc?id={file_id}", destination, quiet=False)
'''
# Out:
# '\nimport gdown\nfile_id = "1E_JwOdHKmFVzZgOPa8xABGLAc37RsHbW"\ndestination = "otros-delitos.csv"  # Nombre del archivo local\ngdown.download(f"https://drive.google.com/uc?id={file_id}", destination, quiet=False)\n'

# %%
# Carga de datos
df = pd.read_csv('../../Data/raw/otros-delitos.csv', sep=';' , encoding='utf-8-sig')

# %%
df.head().T
# Out:
#                                      0                    1                2  \
# ﻿ID_EVENTO                   ABI161166            BAF181532         BBB27344
# DELITO             VIOLENCIA DOMÉSTICA  VIOLENCIA DOMÉSTICA            HURTO
# VICT_RAP                NO CORRESPONDE       NO CORRESPONDE   NO CORRESPONDE
# VICT_HUR                NO CORRESPONDE       NO CORRESPONDE      DE VEHICULO
# TENTATIVA                           NO                   NO               NO
# FECHA                       01.01.2013           14.01.2013       01.01.2013
# AÑO                               2013                 2013             2013
# MES                              ENERO                ENERO            ENERO
# SEMESTRE               PRIMER SEMESTRE      PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                      ENE-MAR              ENE-MAR          ENE-MAR
# DIA_SEMANA                      MARTES                LUNES           MARTES
# HORA                                 0                    8         SIN DATO
# DEPTO                       MONTEVIDEO           MONTEVIDEO        MALDONADO
# JURISDICCION              SECCIONAL 10         SECCIONAL 16      SECCIONAL 1
# BARRIO_MONTEVIDEO              POCITOS            ITUZAINGO   NO CORRESPONDE
#
#                                  3                        4
# ﻿ID_EVENTO               BBP141672                 BDF45548
# DELITO                    LESIONES      VIOLENCIA DOMÉSTICA
# VICT_RAP            NO CORRESPONDE           NO CORRESPONDE
# VICT_HUR            NO CORRESPONDE           NO CORRESPONDE
# TENTATIVA                       SI                       NO
# FECHA                   16.01.2013               01.01.2013
# AÑO                           2013                     2013
# MES                          ENERO                    ENERO
# SEMESTRE           PRIMER SEMESTRE          PRIMER SEMESTRE
# TRIMESTRE                  ENE-MAR                  ENE-MAR
# DIA_SEMANA               MIERCOLES                   MARTES
# HORA                             1                       19
# DEPTO                   MONTEVIDEO               MONTEVIDEO
# JURISDICCION          SECCIONAL 19             SECCIONAL 21
# BARRIO_MONTEVIDEO          LA TEJA  COLON CENTRO Y NOROESTE

# %% [markdown]
# ### 1. EDA y DATA CLEANING

# %%
df.describe(include='all').T
# Out:
#                        count   unique              top     freq         mean  \
# ﻿ID_EVENTO           2206963  2206963       TPW1999952        1          NaN
# DELITO               2206963        5            HURTO  1376642          NaN
# VICT_RAP             2206963       12   NO CORRESPONDE  1934297          NaN
# VICT_HUR             2206963        8   NO CORRESPONDE   830321          NaN
# TENTATIVA            2206963        2               NO  2125703          NaN
# FECHA                2206963     4291       16.02.2020      778          NaN
# AÑO                2206963.0      NaN              NaN      NaN  2018.536126
# MES                  2206963       12            ENERO   205049          NaN
# SEMESTRE             2206963        2  PRIMER SEMESTRE  1140258          NaN
# TRIMESTRE            2206963        4          ENE-MAR   596589          NaN
# DIA_SEMANA           2206963        7          VIERNES   324491          NaN
# HORA                 2206963       25         SIN DATO  1228944          NaN
# DEPTO                2206963       19       MONTEVIDEO  1062823          NaN
# JURISDICCION         2206963       33      SECCIONAL 1   284024          NaN
# BARRIO_MONTEVIDEO    2206963       64   NO CORRESPONDE  1144140          NaN
#
#                         std     min     25%     50%     75%     max
# ﻿ID_EVENTO              NaN     NaN     NaN     NaN     NaN     NaN
# DELITO                  NaN     NaN     NaN     NaN     NaN     NaN
# VICT_RAP                NaN     NaN     NaN     NaN     NaN     NaN
# VICT_HUR                NaN     NaN     NaN     NaN     NaN     NaN
# TENTATIVA               NaN     NaN     NaN     NaN     NaN     NaN
# FECHA                   NaN     NaN     NaN     NaN     NaN     NaN
# AÑO                3.278818  2013.0  2016.0  2019.0  2021.0  2024.0
# MES                     NaN     NaN     NaN     NaN     NaN     NaN
# SEMESTRE                NaN     NaN     NaN     NaN     NaN     NaN
# TRIMESTRE               NaN     NaN     NaN     NaN     NaN     NaN
# DIA_SEMANA              NaN     NaN     NaN     NaN     NaN     NaN
# HORA                    NaN     NaN     NaN     NaN     NaN     NaN
# DEPTO                   NaN     NaN     NaN     NaN     NaN     NaN
# JURISDICCION            NaN     NaN     NaN     NaN     NaN     NaN
# BARRIO_MONTEVIDEO       NaN     NaN     NaN     NaN     NaN     NaN

# %%
# Show the unique values of the column 'DELITO'
df['DELITO'].unique()
# Out:
# array(['VIOLENCIA DOMÉSTICA', 'HURTO', 'LESIONES', 'RAPIÑA', 'ABIGEATO'],
#       dtype=object)

# %%
# Show the unique values of the column 'BARRIO_MOONTEVIDEO'
df['BARRIO_MONTEVIDEO'].unique()
# Out:
# array(['POCITOS', 'ITUZAINGO', 'NO CORRESPONDE', 'LA TEJA',
#        'COLON CENTRO Y NOROESTE', 'AIRES PUROS', 'CAPURRO, BELLA VISTA',
#        'TRES CRUCES', 'CENTRO', 'LA COMERCIAL',
#        'PQUE. BATLLE, V. DOLORES', 'PUNTA GORDA',
#        'JARDINES DEL HIPODROMO', 'LAS CANTERAS', 'MALVIN NORTE', 'SAYAGO',
#        'BUCEO', 'BAÑADOS DE CARRASCO', 'PUNTA CARRETAS',
#        'MERCADO MODELO, BOLIVAR', 'UNION', 'CORDON',
#        'VILLA GARCIA, MANGA RURAL', 'PRADO, NUEVA SAVONA', 'NUEVO PARIS',
#        'CERRITO', 'CERRO', 'PTA. RIELES, BELLA ITALIA',
#        'PASO DE LA ARENA', 'BELVEDERE', 'LA PALOMA, TOMKINSON',
#        'CASAVALLE', 'VILLA ESPAÑOLA', 'TRES OMBUES, VICTORIA',
#        'CASABO, PAJAS BLANCAS', 'MALVIN', 'MANGA', 'CARRASCO NORTE',
#        'JACINTO VERA', 'LA BLANQUEADA', 'SIN CLASIFICAR',
#        'LEZICA, MELILLA', 'PIEDRAS BLANCAS', 'LARRAÑAGA',
#        'COLON SURESTE, ABAYUBA', 'CASTRO, P. CASTELLANOS',
#        'FLOR DE MAROÑAS', 'PALERMO', 'ATAHUALPA', 'PASO DE LAS DURANAS',
#        'PEÑAROL, LAVALLEJA', 'LAS ACACIAS', 'MANGA, TOLEDO CHICO',
#        'AGUADA', 'CIUDAD VIEJA', 'BARRIO SUR', 'CONCILIACION', 'REDUCTO',
#        'VILLA MUÑOZ, RETIRO', 'PARQUE RODO', 'BRAZO ORIENTAL', 'CARRASCO',
#        'MAROÑAS, PARQUE GUARANI', 'LA FIGURITA'], dtype=object)

# %%
# Count the unique values of the column 'BARRIO_MONTEVIDEO'
df['BARRIO_MONTEVIDEO'].nunique()
# Out:
# 64

# %% [markdown]
# ### 1.1. MONTEVIDEO

# %%
# Create a copy of the DataFrame with only data from MONTEVIDEO
df_mvd = df[df['DEPTO'] == 'MONTEVIDEO'].copy()

# %%
df_mvd.head().T
# Out:
#                                      0                    1                3  \
# ﻿ID_EVENTO                   ABI161166            BAF181532        BBP141672
# DELITO             VIOLENCIA DOMÉSTICA  VIOLENCIA DOMÉSTICA         LESIONES
# VICT_RAP                NO CORRESPONDE       NO CORRESPONDE   NO CORRESPONDE
# VICT_HUR                NO CORRESPONDE       NO CORRESPONDE   NO CORRESPONDE
# TENTATIVA                           NO                   NO               SI
# FECHA                       01.01.2013           14.01.2013       16.01.2013
# AÑO                               2013                 2013             2013
# MES                              ENERO                ENERO            ENERO
# SEMESTRE               PRIMER SEMESTRE      PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                      ENE-MAR              ENE-MAR          ENE-MAR
# DIA_SEMANA                      MARTES                LUNES        MIERCOLES
# HORA                                 0                    8                1
# DEPTO                       MONTEVIDEO           MONTEVIDEO       MONTEVIDEO
# JURISDICCION              SECCIONAL 10         SECCIONAL 16     SECCIONAL 19
# BARRIO_MONTEVIDEO              POCITOS            ITUZAINGO          LA TEJA
#
#                                          4                    5
# ﻿ID_EVENTO                        BDF45548             BFM40350
# DELITO                 VIOLENCIA DOMÉSTICA  VIOLENCIA DOMÉSTICA
# VICT_RAP                    NO CORRESPONDE       NO CORRESPONDE
# VICT_HUR                    NO CORRESPONDE       NO CORRESPONDE
# TENTATIVA                               NO                   NO
# FECHA                           01.01.2013           01.01.2013
# AÑO                                   2013                 2013
# MES                                  ENERO                ENERO
# SEMESTRE                   PRIMER SEMESTRE      PRIMER SEMESTRE
# TRIMESTRE                          ENE-MAR              ENE-MAR
# DIA_SEMANA                          MARTES               MARTES
# HORA                                    19                    0
# DEPTO                           MONTEVIDEO           MONTEVIDEO
# JURISDICCION                  SECCIONAL 21         SECCIONAL 12
# BARRIO_MONTEVIDEO  COLON CENTRO Y NOROESTE          AIRES PUROS

# %%
# Looking for missing values
df_mvd.isnull().sum()
# Out:
# ID_EVENTO           0
# DELITO               0
# VICT_RAP             0
# VICT_HUR             0
# TENTATIVA            0
# FECHA                0
# AÑO                  0
# MES                  0
# SEMESTRE             0
# TRIMESTRE            0
# DIA_SEMANA           0
# HORA                 0
# DEPTO                0
# JURISDICCION         0
# BARRIO_MONTEVIDEO    0
# dtype: int64

# %%
df_mvd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1062823 entries, 0 to 2206962
# Data columns (total 15 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   ﻿ID_EVENTO         1062823 non-null  object
#  1   DELITO             1062823 non-null  object
#  2   VICT_RAP           1062823 non-null  object
#  3   VICT_HUR           1062823 non-null  object
#  4   TENTATIVA          1062823 non-null  object
#  5   FECHA              1062823 non-null  object
#  6   AÑO                1062823 non-null  int64
#  7   MES                1062823 non-null  object
#  8   SEMESTRE           1062823 non-null  object
#  9   TRIMESTRE          1062823 non-null  object
#  10  DIA_SEMANA         1062823 non-null  object
#  11  HORA               1062823 non-null  object
#  12  DEPTO              1062823 non-null  object
#  13  JURISDICCION       1062823 non-null  object
#  14  BARRIO_MONTEVIDEO  1062823 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 129.7+ MB

# %%
df_mvd.describe(include='all').T
# Out:
#                        count   unique              top     freq         mean  \
# ﻿ID_EVENTO           1062823  1062823       TPW1999952        1          NaN
# DELITO               1062823        5            HURTO   650085          NaN
# VICT_RAP             1062823       12   NO CORRESPONDE   842264          NaN
# VICT_HUR             1062823        8   NO CORRESPONDE   412738          NaN
# TENTATIVA            1062823        2               NO  1016045          NaN
# FECHA                1062823     4291       02.03.2020      385          NaN
# AÑO                1062823.0      NaN              NaN      NaN  2018.608971
# MES                  1062823       12            MARZO    99974          NaN
# SEMESTRE             1062823        2  PRIMER SEMESTRE   549193          NaN
# TRIMESTRE            1062823        4          ENE-MAR   283637          NaN
# DIA_SEMANA           1062823        7          VIERNES   159988          NaN
# HORA                 1062823       25         SIN DATO   529343          NaN
# DEPTO                1062823        1       MONTEVIDEO  1062823          NaN
# JURISDICCION         1062823       27     SECCIONAL 19    78910          NaN
# BARRIO_MONTEVIDEO    1062823       63            UNION    51098          NaN
#
#                         std     min     25%     50%     75%     max
# ﻿ID_EVENTO              NaN     NaN     NaN     NaN     NaN     NaN
# DELITO                  NaN     NaN     NaN     NaN     NaN     NaN
# VICT_RAP                NaN     NaN     NaN     NaN     NaN     NaN
# VICT_HUR                NaN     NaN     NaN     NaN     NaN     NaN
# TENTATIVA               NaN     NaN     NaN     NaN     NaN     NaN
# FECHA                   NaN     NaN     NaN     NaN     NaN     NaN
# AÑO                3.302302  2013.0  2016.0  2019.0  2021.0  2024.0
# MES                     NaN     NaN     NaN     NaN     NaN     NaN
# SEMESTRE                NaN     NaN     NaN     NaN     NaN     NaN
# TRIMESTRE               NaN     NaN     NaN     NaN     NaN     NaN
# DIA_SEMANA              NaN     NaN     NaN     NaN     NaN     NaN
# HORA                    NaN     NaN     NaN     NaN     NaN     NaN
# DEPTO                   NaN     NaN     NaN     NaN     NaN     NaN
# JURISDICCION            NaN     NaN     NaN     NaN     NaN     NaN
# BARRIO_MONTEVIDEO       NaN     NaN     NaN     NaN     NaN     NaN

# %%
# Variable ID_EVENTO tiene caracteres especiales en su nombre
print(df_mvd.columns.tolist())
# Out:
# ['\ufeffID_EVENTO', 'DELITO', 'VICT_RAP', 'VICT_HUR', 'TENTATIVA', 'FECHA', 'AÑO', 'MES', 'SEMESTRE', 'TRIMESTRE', 'DIA_SEMANA', 'HORA', 'DEPTO', 'JURISDICCION', 'BARRIO_MONTEVIDEO']

# %%
# Removiendo el caracteres no deseados de nombres de variables
df_mvd.columns = df_mvd.columns.str.replace('\ufeff', '')

# %%
# Chequeando que se hayan removido los caracteres no deseados
print(df_mvd.columns.tolist())
# Out:
# ['ID_EVENTO', 'DELITO', 'VICT_RAP', 'VICT_HUR', 'TENTATIVA', 'FECHA', 'AÑO', 'MES', 'SEMESTRE', 'TRIMESTRE', 'DIA_SEMANA', 'HORA', 'DEPTO', 'JURISDICCION', 'BARRIO_MONTEVIDEO']

# %%
# Eliminando variables innecesarias
df_mvd.drop(columns=['ID_EVENTO', 'VICT_RAP', 'VICT_HUR', 'DEPTO'], inplace=True)

# %%
df_mvd.head().T
# Out:
#                                      0                    1                3  \
# DELITO             VIOLENCIA DOMÉSTICA  VIOLENCIA DOMÉSTICA         LESIONES
# TENTATIVA                           NO                   NO               SI
# FECHA                       01.01.2013           14.01.2013       16.01.2013
# AÑO                               2013                 2013             2013
# MES                              ENERO                ENERO            ENERO
# SEMESTRE               PRIMER SEMESTRE      PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                      ENE-MAR              ENE-MAR          ENE-MAR
# DIA_SEMANA                      MARTES                LUNES        MIERCOLES
# HORA                                 0                    8                1
# JURISDICCION              SECCIONAL 10         SECCIONAL 16     SECCIONAL 19
# BARRIO_MONTEVIDEO              POCITOS            ITUZAINGO          LA TEJA
#
#                                          4                    5
# DELITO                 VIOLENCIA DOMÉSTICA  VIOLENCIA DOMÉSTICA
# TENTATIVA                               NO                   NO
# FECHA                           01.01.2013           01.01.2013
# AÑO                                   2013                 2013
# MES                                  ENERO                ENERO
# SEMESTRE                   PRIMER SEMESTRE      PRIMER SEMESTRE
# TRIMESTRE                          ENE-MAR              ENE-MAR
# DIA_SEMANA                          MARTES               MARTES
# HORA                                    19                    0
# JURISDICCION                  SECCIONAL 21         SECCIONAL 12
# BARRIO_MONTEVIDEO  COLON CENTRO Y NOROESTE          AIRES PUROS

# %%
# Graficos de delitos en Montevideo

sns.countplot(data=df_mvd, x='DELITO', order=df_mvd['DELITO'].value_counts().index, hue= 'TENTATIVA', palette='viridis')
plt.xticks(rotation=45)
plt.show()

# %%
# Eliminamos registros de violencia domestica y abigeato
df_mvd = df_mvd[df_mvd['DELITO'] != 'VIOLENCIA DOMÉSTICA']
df_mvd = df_mvd[df_mvd['DELITO'] != 'ABIGEATO']

# %% [markdown]
# - La mayoria de delitos son hurtos y rapiñas y en su mayoría son crímenes consumados.
# - Violencia doméstica ocurre en hogares deberíamos eliminarla? No porque aumentando el patrullaje se llegaría más rapido al lugar de la denuncia.
# - Montevideo tiene una zona rural por eso figura algun Abigeato (robo de animales), igual son muy pocos

# %%
# Delitos por barrios de Montevideo
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd, x='BARRIO_MONTEVIDEO', order=df_mvd['BARRIO_MONTEVIDEO'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Hay algunos datos sin identificar barrio (SIN IDENTIFICAR), son muy pocos

# %%
# Cantidad de delitos por hora

plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd, x='HORA', order=df_mvd['HORA'].value_counts(normalize=True).index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Aproximadamente la mitad de los registros no tienen hora asignada ya que los hurtos muchas veces no se sabe a que hora fueron.

# %%
# Delitos por hora y tipo de delito
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd, x='HORA', hue='DELITO')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Todos los delitos sin datos de hora son de hurtos.

# %%
# Transformando columna 'FECHA' a datetime
df_mvd['FECHA'] = pd.to_datetime(df_mvd['FECHA'], format='%d.%m.%Y')

# %%
# Chequeando columna 'FECHA' transformada
df_mvd['FECHA'].describe()
# Out:
# count                           919970
# mean     2019-01-31 03:38:10.120765440
# min                2013-01-01 00:00:00
# 25%                2016-04-26 00:00:00
# 50%                2019-03-26 00:00:00
# 75%                2021-11-12 00:00:00
# max                2024-09-30 00:00:00
# Name: FECHA, dtype: object

# %%
# Delitos por dia de la semana
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd, x='DIA_SEMANA', order=df_mvd['DIA_SEMANA'].value_counts().index)
plt.show()

# %% [markdown]
# - Los dias de fin de semama ocurren menor cantidad de delitos.

# %%
# Delitos por dia de la semana y tipo de delito
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd, x='DIA_SEMANA', order=df_mvd['DIA_SEMANA'].value_counts().index, hue='DELITO')
plt.show()

# %% [markdown]
# - No hay grandes diferencias en las proporciones de los delitos entrelos diferentes días de la semana.

# %%
# Distribución de delitos por barrio en Montevideo
delito_orden = df_mvd['DELITO'].value_counts().index.tolist()

g = sns.FacetGrid(df_mvd, col="BARRIO_MONTEVIDEO", col_wrap=4, height=4, aspect=1.5, sharex=False, sharey=False)
g.map(sns.countplot, "DELITO", order=delito_orden, hue='DELITO', palette='viridis', data=df_mvd)

# Rotar las etiquetas de cada subgráfico
for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Ajustar espaciado entre subgráficos
g.fig.subplots_adjust(hspace=0.5, wspace=0.3)

# Agregar título general
g.fig.suptitle("Distribución de delitos por barrio en Montevideo", y=1.02, fontsize=16)

# Mostrar la figura
plt.show()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\1813897351.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %% [markdown]
# - En todos los barrios, el mayor delito es el hurto luego hay diferencias en rapiñas y violencia doméstica.
# - En barrios de mayor poder adquisitivo, las rapiñas son el segundo delito mientras que en algunos de menor poder, la violencia doméstica llega a nieveles de rapiña.

# %% [markdown]
# ### OBSERVACIONES:
#
# - La mayoria de delitos son hurtos y rapiñas (hurtos violentos).
# - La mayoría son delitos consumados.
#
# - Violencia doméstica ocurre en hogares deberíamos eliminarla? No porque aumentando el patrullaje se llegaría más rapido al lugar de la denuncia.
#
# - Montevideo tiene una zona rural por eso figura algun Abigeato (robo de animales), igual son muy pocos.
# - Hay algunos datos sin identificar barrio (SIN IDENTIFICAR), son muy pocos.
# - Aproximadamente la mitad de los registros no tienen hora asignada ya que los hurtos muchas veces no se sabe a que hora fueron.
# - Los hurtos que tienen hora asignada son de hurtos a transeuntes.
#
# - Los dias de fin de semama ocurren menor cantidad de delitos.
#
# - En todos los barrios, el mayor delito es el hurto luego hay diferencias en rapiñas y violencia doméstica.
# - En barrios de mayor poder adquisitivo, las rapiñas son el segundo delito mientras que en algunos de menor poder, la violencia doméstica llega a nieveles de rapiña.

# %%
df_mvd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 919970 entries, 3 to 2206962
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DELITO             919970 non-null  object
#  1   TENTATIVA          919970 non-null  object
#  2   FECHA              919970 non-null  datetime64[ns]
#  3   AÑO                919970 non-null  int64
#  4   MES                919970 non-null  object
#  5   SEMESTRE           919970 non-null  object
#  6   TRIMESTRE          919970 non-null  object
#  7   DIA_SEMANA         919970 non-null  object
#  8   HORA               919970 non-null  object
#  9   JURISDICCION       919970 non-null  object
#  10  BARRIO_MONTEVIDEO  919970 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 84.2+ MB

# %% [markdown]
# #### TRATAMIENTO DE DATOS SIN HORA
# - Si se eliminan delitos sin hora, se eliminan hurtos a viviendas, vehículos, etc cuando se dan sin la presencia del dueño.
# - justificacion puede ser que el modelo de ML apuntaria ayudar a disminuir delitos de rapiñas, violencia y hurtos a transeuntes, por lo tanto eliminamos Abigeatos y Violéncia doméstica.

# %%
# Eliminando datos con hora SIN DATO 
df_mvd_red = df_mvd[(df_mvd['HORA'] != 'SIN DATO') & (df_mvd['DELITO'] != 'ABIGEATO')].copy()

# %%
df_mvd_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 390824 entries, 3 to 2206959
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DELITO             390824 non-null  object
#  1   TENTATIVA          390824 non-null  object
#  2   FECHA              390824 non-null  datetime64[ns]
#  3   AÑO                390824 non-null  int64
#  4   MES                390824 non-null  object
#  5   SEMESTRE           390824 non-null  object
#  6   TRIMESTRE          390824 non-null  object
#  7   DIA_SEMANA         390824 non-null  object
#  8   HORA               390824 non-null  object
#  9   JURISDICCION       390824 non-null  object
#  10  BARRIO_MONTEVIDEO  390824 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 35.8+ MB

# %% [markdown]
# - Quedan solamente **533.480 registros**

# %%
# Delitos por hora y tipo de delito
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd_red, x='HORA', order=df_mvd_red['HORA'].value_counts().index, hue='DELITO')
plt.show()

# %%
# Delitos por dia de la semana y tipo de delito
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd_red, x='DIA_SEMANA', order=df_mvd['DIA_SEMANA'].value_counts().index)
plt.show()

# %%
# Delitos por dia de la semana y tipo de delito
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd_red, x='DIA_SEMANA', order=df_mvd['DIA_SEMANA'].value_counts().index, hue='DELITO')
plt.show()

# %%
# Delitos por año
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd_red, x='AÑO', order=df_mvd_red['AÑO'].value_counts().index)
plt.show()

# %%
# Creando una nueva columna 'MES' con el numero del mes a partir de la columna 'FECHA'
df_mvd_red['MES_NUM'] = df_mvd_red['FECHA'].dt.month

# %%
df_mvd_red.head().T
# Out:
#                                     3                    24  \
# DELITO                        LESIONES             LESIONES
# TENTATIVA                           SI                   NO
# FECHA              2013-01-16 00:00:00  2013-01-09 00:00:00
# AÑO                               2013                 2013
# MES                              ENERO                ENERO
# SEMESTRE               PRIMER SEMESTRE      PRIMER SEMESTRE
# TRIMESTRE                      ENE-MAR              ENE-MAR
# DIA_SEMANA                   MIERCOLES            MIERCOLES
# HORA                                 1                   19
# JURISDICCION              SECCIONAL 19         SECCIONAL 15
# BARRIO_MONTEVIDEO              LA TEJA         MALVIN NORTE
# MES_NUM                              1                    1
#
#                                     25                       29  \
# DELITO                          RAPIÑA                    HURTO
# TENTATIVA                           NO                       NO
# FECHA              2013-01-03 00:00:00      2013-01-09 00:00:00
# AÑO                               2013                     2013
# MES                              ENERO                    ENERO
# SEMESTRE               PRIMER SEMESTRE          PRIMER SEMESTRE
# TRIMESTRE                      ENE-MAR                  ENE-MAR
# DIA_SEMANA                      JUEVES                MIERCOLES
# HORA                                23                       16
# JURISDICCION               SECCIONAL 8             SECCIONAL 21
# BARRIO_MONTEVIDEO               SAYAGO  COLON CENTRO Y NOROESTE
# MES_NUM                              1                        1
#
#                                     33
# DELITO                           HURTO
# TENTATIVA                           NO
# FECHA              2013-01-09 00:00:00
# AÑO                               2013
# MES                              ENERO
# SEMESTRE               PRIMER SEMESTRE
# TRIMESTRE                      ENE-MAR
# DIA_SEMANA                   MIERCOLES
# HORA                                18
# JURISDICCION               SECCIONAL 4
# BARRIO_MONTEVIDEO         LA COMERCIAL
# MES_NUM                              1

# %%
# Agrupando datos por año  mes, barrio, dia, hora etc.
df_mvd_red_grup = df_mvd_red.groupby(['AÑO', 'MES', 'BARRIO_MONTEVIDEO', 'DIA_SEMANA', 'HORA']).size().reset_index(name='count_delitos')

# %%
df_mvd_red_grup.describe()
# Out:
#                  AÑO  count_delitos
# count  313861.000000  313861.000000
# mean     2018.481904       1.245214
# std         3.300878       0.556261
# min      2013.000000       1.000000
# 25%      2016.000000       1.000000
# 50%      2019.000000       1.000000
# 75%      2021.000000       1.000000
# max      2024.000000      11.000000

# %%
# histograma de count_delitos
plt.figure(figsize=(15, 5))
sns.histplot(data=df_mvd_red_grup, x='count_delitos', bins=20)
plt.show()

# %%
df_mvd_red_grup.head()
# Out:
#     AÑO    MES BARRIO_MONTEVIDEO DIA_SEMANA HORA  count_delitos
# 0  2013  ABRIL            AGUADA    DOMINGO   12              1
# 1  2013  ABRIL            AGUADA    DOMINGO   15              1
# 2  2013  ABRIL            AGUADA    DOMINGO   20              1
# 3  2013  ABRIL            AGUADA    DOMINGO   23              1
# 4  2013  ABRIL            AGUADA    DOMINGO    3              1

# %% [markdown]
# - Quedan registros agrupados pero en su mayoría cada registro tiene 1 solo crimen
# - Habría que agrupar por turno por ejemplo madrugada, mañana, tarde y noche

# %%
# Distribución de delitos por barrio en Montevideo
delito_orden = df_mvd_red['DELITO'].value_counts().index.tolist()

g = sns.FacetGrid(df_mvd_red, col="BARRIO_MONTEVIDEO", col_wrap=4, height=4, aspect=1.5, sharex=False, sharey=False)
g.map(sns.countplot, "DELITO", order=delito_orden, hue='DELITO', palette='viridis', data=df_mvd)

# Rotar las etiquetas de cada subgráfico
for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Ajustar espaciado entre subgráficos
g.fig.subplots_adjust(hspace=0.5, wspace=0.3)

# Agregar título general
g.fig.suptitle("Distribución de delitos por barrio en Montevideo", y=1.02, fontsize=16)

# Mostrar la figura
plt.show()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_6196\985779430.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
# Función para asignar horario del día

def asignar_horario_dia(hora):
    if pd.isnull(hora):
        return np.nan
    if hora < 6:
        return 'Madrugada'
    elif hora < 12:
        return 'Mañana'
    elif hora < 18:
        return 'Tarde'
    else:
        return 'Noche'

# %%
# Convertir Hora a numérico, manejando errores
df_mvd_red['HORA'] = pd.to_numeric(df_mvd_red['HORA'], errors='coerce')

# %%
# Aplicar función asignar_horario_dia a la columna 'HORA'
df_mvd_red['HORARIO_DIA'] = df_mvd_red['HORA'].apply(asignar_horario_dia)

# %%
# Chequear la nueva columna 'HORARIO_DIA'
df_mvd_red['HORARIO_DIA'].value_counts()
# Out:
# HORARIO_DIA
# Noche        137864
# Tarde        122330
# Mañana        66435
# Madrugada     64195
# Name: count, dtype: int64

# %% [markdown]
# - Hay más deltios por la tarde y noche que en mañana y madrugada

# %%
# Delitos por horario del día
plt.figure(figsize=(15, 5))
sns.countplot(data=df_mvd_red, x='HORARIO_DIA', order=df_mvd_red['HORARIO_DIA'].value_counts().index, hue='DELITO')
plt.show()

# %%
# Agrupando datos por barrio, HORARIO DEL DIA....
df_mvd_red_grup_2 = df_mvd_red.groupby(['AÑO', 'MES', 'BARRIO_MONTEVIDEO', 'DIA_SEMANA', 'HORARIO_DIA', 'SEMESTRE', 'TRIMESTRE']).size().reset_index(name='count_delitos')

# %%
df_mvd_red_grup_2.head()
# Out:
#     AÑO    MES BARRIO_MONTEVIDEO DIA_SEMANA HORARIO_DIA         SEMESTRE  \
# 0  2013  ABRIL            AGUADA    DOMINGO   Madrugada  PRIMER SEMESTRE
# 1  2013  ABRIL            AGUADA    DOMINGO       Noche  PRIMER SEMESTRE
# 2  2013  ABRIL            AGUADA    DOMINGO       Tarde  PRIMER SEMESTRE
# 3  2013  ABRIL            AGUADA     JUEVES       Noche  PRIMER SEMESTRE
# 4  2013  ABRIL            AGUADA     JUEVES       Tarde  PRIMER SEMESTRE
#
#   TRIMESTRE  count_delitos
# 0   ABR-JUN              1
# 1   ABR-JUN              2
# 2   ABR-JUN              2
# 3   ABR-JUN              1
# 4   ABR-JUN              3

# %%
df_mvd_red_grup_2.describe()
# Out:
#                  AÑO  count_delitos
# count  164253.000000  164253.000000
# mean     2018.443858       2.379403
# std         3.343148       1.752806
# min      2013.000000       1.000000
# 25%      2016.000000       1.000000
# 50%      2019.000000       2.000000
# 75%      2021.000000       3.000000
# max      2024.000000      21.000000

# %%
# Histograma de count_delitos
plt.figure(figsize=(15, 5))
sns.histplot(data=df_mvd_red_grup_2, x='count_delitos', bins=30)
plt.show()

# %%
# Agrupando datos por barrio, DIA....
df_mvd_red_grup_3 = df_mvd_red.groupby(['AÑO', 'MES', 'BARRIO_MONTEVIDEO', 'DIA_SEMANA', 'SEMESTRE', 'TRIMESTRE']).size().reset_index(name='count_delitos')

# %%
df_mvd_red_grup_3.head()
# Out:
#     AÑO    MES BARRIO_MONTEVIDEO DIA_SEMANA         SEMESTRE TRIMESTRE  \
# 0  2013  ABRIL            AGUADA    DOMINGO  PRIMER SEMESTRE   ABR-JUN
# 1  2013  ABRIL            AGUADA     JUEVES  PRIMER SEMESTRE   ABR-JUN
# 2  2013  ABRIL            AGUADA      LUNES  PRIMER SEMESTRE   ABR-JUN
# 3  2013  ABRIL            AGUADA     MARTES  PRIMER SEMESTRE   ABR-JUN
# 4  2013  ABRIL            AGUADA  MIERCOLES  PRIMER SEMESTRE   ABR-JUN
#
#    count_delitos
# 0              5
# 1              4
# 2              6
# 3              7
# 4              8

# %%
df_mvd_red_grup_3.describe()
# Out:
#                 AÑO  count_delitos
# count  59270.000000   59270.000000
# mean    2018.374135       6.593960
# std        3.386029       4.796069
# min     2013.000000       1.000000
# 25%     2015.000000       3.000000
# 50%     2018.000000       5.000000
# 75%     2021.000000       9.000000
# max     2024.000000      41.000000

# %%
# Histograma de count_delitos
plt.figure(figsize=(15, 5))
sns.histplot(data=df_mvd_red_grup_3, x='count_delitos', bins=50)
plt.show()

# %% [markdown]
# - Lo mejor sería que la menor granulosidad sea por día para tener un mayor número de crímenes
# - De esta forma se pueden usar los delitos sin fecha

# %% [markdown]
# ### Agruparemos por día
# ### Usamos todos los delitos incluyendo los sin hora registrada

# %%
df_mvd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 919970 entries, 3 to 2206962
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DELITO             919970 non-null  object
#  1   TENTATIVA          919970 non-null  object
#  2   FECHA              919970 non-null  datetime64[ns]
#  3   AÑO                919970 non-null  int64
#  4   MES                919970 non-null  object
#  5   SEMESTRE           919970 non-null  object
#  6   TRIMESTRE          919970 non-null  object
#  7   DIA_SEMANA         919970 non-null  object
#  8   HORA               919970 non-null  object
#  9   JURISDICCION       919970 non-null  object
#  10  BARRIO_MONTEVIDEO  919970 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 84.2+ MB

# %% [markdown]
# - Fecha está en formato string la transformamos en DateTime

# %%
# Transformando columna 'FECHA' a datetime
df_mvd['FECHA'] = pd.to_datetime(df_mvd['FECHA'], format='%d.%m.%Y')

# %%
# Creando una nueva columa numero del dia del mes
df_mvd['DIA_MES'] = df_mvd['FECHA'].dt.day

# %%
# Se crea nueva variable que indica semana del mes
df_mvd['SEMANA_MES'] = df_mvd['DIA_MES'].apply(lambda x: x // 7 + 1)

# %%
# Modificamos la columna 'MES' con el numero del mes a partir de la columna 'FECHA'
df_mvd['MES'] = df_mvd['FECHA'].dt.month

# %%
df_mvd.head()
# Out:
#       DELITO TENTATIVA      FECHA   AÑO  MES         SEMESTRE TRIMESTRE  \
# 3   LESIONES        SI 2013-01-16  2013    1  PRIMER SEMESTRE   ENE-MAR
# 8      HURTO        NO 2013-01-04  2013    1  PRIMER SEMESTRE   ENE-MAR
# 13     HURTO        NO 2013-01-01  2013    1  PRIMER SEMESTRE   ENE-MAR
# 17     HURTO        NO 2013-01-09  2013    1  PRIMER SEMESTRE   ENE-MAR
# 24  LESIONES        NO 2013-01-09  2013    1  PRIMER SEMESTRE   ENE-MAR
#
#    DIA_SEMANA      HORA  JURISDICCION         BARRIO_MONTEVIDEO  DIA_MES  \
# 3   MIERCOLES         1  SECCIONAL 19                   LA TEJA       16
# 8     VIERNES  SIN DATO   SECCIONAL 9               TRES CRUCES        4
# 13     MARTES  SIN DATO   SECCIONAL 9  PQUE. BATLLE, V. DOLORES        1
# 17  MIERCOLES  SIN DATO  SECCIONAL 14               PUNTA GORDA        9
# 24  MIERCOLES        19  SECCIONAL 15              MALVIN NORTE        9
#
#     SEMANA_MES
# 3            3
# 8            1
# 13           1
# 17           2
# 24           2

# %%
# Agrupando datos por Barrio y día
df_mvd_group = df_mvd.groupby(['BARRIO_MONTEVIDEO','FECHA','AÑO','MES','DIA_MES','DIA_SEMANA','SEMANA_MES','SEMESTRE','TRIMESTRE']).size().reset_index(name='count_delitos')

# %% [markdown]
# - Cada fila corresponde a un dia en un barrio específico y se cuenta la cantidad de delitos.

# %%
df_mvd_group.head()
# Out:
#   BARRIO_MONTEVIDEO      FECHA   AÑO  MES  DIA_MES DIA_SEMANA  SEMANA_MES  \
# 0            AGUADA 2013-01-02  2013    1        2  MIERCOLES           1
# 1            AGUADA 2013-01-03  2013    1        3     JUEVES           1
# 2            AGUADA 2013-01-04  2013    1        4    VIERNES           1
# 3            AGUADA 2013-01-05  2013    1        5     SABADO           1
# 4            AGUADA 2013-01-06  2013    1        6    DOMINGO           1
#
#           SEMESTRE TRIMESTRE  count_delitos
# 0  PRIMER SEMESTRE   ENE-MAR              1
# 1  PRIMER SEMESTRE   ENE-MAR              1
# 2  PRIMER SEMESTRE   ENE-MAR              6
# 3  PRIMER SEMESTRE   ENE-MAR              1
# 4  PRIMER SEMESTRE   ENE-MAR              4

# %%
df_mvd_group.describe()
# Out:
#                                FECHA            AÑO            MES  \
# count                         243699  243699.000000  243699.000000
# mean   2018-11-29 09:05:28.610293248    2018.421032       6.411249
# min              2013-01-01 00:00:00    2013.000000       1.000000
# 25%              2016-01-03 00:00:00    2016.000000       3.000000
# 50%              2018-12-12 00:00:00    2018.000000       6.000000
# 75%              2021-10-26 12:00:00    2021.000000       9.000000
# max              2024-09-30 00:00:00    2024.000000      12.000000
# std                              NaN       3.375360       3.424247
#
#              DIA_MES     SEMANA_MES  count_delitos
# count  243699.000000  243699.000000  243699.000000
# mean       15.740048       2.833106       3.775026
# min         1.000000       1.000000       1.000000
# 25%         8.000000       2.000000       2.000000
# 50%        16.000000       3.000000       3.000000
# 75%        23.000000       4.000000       5.000000
# max        31.000000       5.000000      63.000000
# std         8.798501       1.293060       2.745162

# %%
# Histograma de count_delitos
plt.figure(figsize=(15, 5))
sns.histplot(data=df_mvd_group, x='count_delitos', bins=70, color='red')
plt.show()

# %%
df_mvd_group['BARRIO_MONTEVIDEO'].value_counts()
# Out:
# BARRIO_MONTEVIDEO
# UNION                       4290
# CORDON                      4288
# POCITOS                     4283
# CENTRO                      4278
# PQUE. BATLLE, V. DOLORES    4272
#                             ...
# REDUCTO                     3293
# PALERMO                     3233
# ATAHUALPA                   3135
# LA FIGURITA                 3114
# SIN CLASIFICAR              1831
# Name: count, Length: 63, dtype: int64

# %% [markdown]
# - Hay 1899 datos con barrios sin especificar
# - Se eliminan esos datos

# %%
df_mvd_group.drop(df_mvd_group[df_mvd_group['BARRIO_MONTEVIDEO'] == 'SIN CLASIFICAR'].index, inplace=True)

# %%
# Contando la cantidad de registros que quedan en el Dataset
df_mvd_group.shape
# Out:
# (241868, 10)

# %% [markdown]
# - Tenemos 248.447 registros de delitos agrupados.

# %% [markdown]
# #### Incorporación de datos de Poblacion por Barrio

# %% [markdown]
# - La variable TURISTICO es binaria, 1 cuando si, 0 cuando no

# %%
# Cargando los datos de poblacion por barrio
df_pob_barrios = pd.read_excel('data/Poblacion.xlsx')

# %%
# Primeras filas del DataFrame
df_pob_barrios.head(50)
# Out:
#            BARRIO_MONTEVIDEO  POBLACION  TURISTICO MUNICIPIO PLAYA  INSE
# 0                  LARRAÑAGA      18509          0         C    NO     9
# 1                    POCITOS      69107          1        CH    SI     9
# 2             PUNTA CARRETAS      24654          1        CH    NO     9
# 3                     AGUADA      19038          0         C    NO     8
# 4                   CARRASCO      14792          1         E    SI     8
# 5               CIUDAD VIEJA      13598          1         B    NO     8
# 6               JACINTO VERA       8204          0         C    NO     8
# 7              LA BLANQUEADA       9585          0        CH    NO     8
# 8                     MALVIN      29085          1         E    SI     8
# 9                PUNTA GORDA      13596          1         E    SI     8
# 10                BARRIO SUR      13953          1         B    NO     7
# 11                     BUCEO      36320          1        CH    SI     7
# 12            CARRASCO NORTE      13020          0         E    NO     7
# 13                    CENTRO      23335          1         B    NO     7
# 14                   PALERMO      12611          1         B    NO     7
# 15               PARQUE RODO      12809          1         B    SI     7
# 16       PASO DE LAS DURANAS      11972          0         G    NO     7
# 17  PQUE. BATLLE, V. DOLORES      29474          0        CH    NO     7
# 18       PRADO, NUEVA SAVONA      19125          0         A    NO     7
# 19               TRES CRUCES      16668          1         B    NO     7
# 20                 BELVEDERE      20120          0         A    NO     6
# 21                    CORDON      44172          1         B    NO     6
# 22               LA FIGURITA       9990          0         C    NO     6
# 23              MALVIN NORTE      17045          0         E    NO     6
# 24   MERCADO MODELO, BOLIVAR      15374          0         C    NO     6
# 25                   REDUCTO      13214          0         C    NO     6
# 26                    SAYAGO      13756          0         G    NO     6
# 27               AIRES PUROS      14657          0        C     NO     5
# 28                 ATAHUALPA       7864          0         C    NO     5
# 29      CAPURRO, BELLA VISTA      16336          0         C    NO     5
# 30              LA COMERCIAL      11110          0         C    NO     5
# 31                     UNION      37488          0         D    NO     5
# 32            VILLA ESPAÑOLA      20792          0         F    NO     5
# 33                   CERRITO      15718          0         D    NO     4
# 34   COLON CENTRO Y NOROESTE      26855          0         G    NO     4
# 35    COLON SURESTE, ABAYUBA      14354          0         G    NO     4
# 36              LAS CANTERAS      21448          0         F    NO     4
# 37   MAROÑAS, PARQUE GUARANI      20401          0         F    NO     4
# 38        PEÑAROL, LAVALLEJA      31748          0         G    NO     4
# 39     TRES OMBUES, VICTORIA      17700          0         A    NO     4
# 40       BAÑADOS DE CARRASCO      13924          0         F    NO     3
# 41     CASABO, PAJAS BLANCAS      29314          0         A    NO     3
# 42                     CERRO      26730          0         A    NO     3
# 43              CONCILIACION      19510          0         G    NO     3
# 44                 ITUZAINGO      12525          0         F    NO     3
# 45    JARDINES DEL HIPODROMO      19098          0         F    NO     3
# 46                   LA TEJA      18308          0         A    NO     3
# 47               LAS ACACIAS      19339          0         D    NO     3
# 48           LEZICA, MELILLA      16929          0         A    NO     3
# 49                     MANGA      19124          0         D    NO     2

# %%
# Información del DataFrame de población por barrios
df_pob_barrios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BARRIO_MONTEVIDEO  62 non-null     object
#  1   POBLACION          62 non-null     int64
#  2   TURISTICO          62 non-null     int64
#  3   MUNICIPIO          62 non-null     object
#  4   PLAYA              62 non-null     object
#  5   INSE               62 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# - Están los datos de los 62 barrios de Montevideo

# %%
# Join de los DataFrames Delitos agrupados y Población por barrio
df_mvd_group_pob = df_mvd_group.merge(df_pob_barrios, on='BARRIO_MONTEVIDEO', how='left', suffixes=('_delitos', '_poblacion'), validate='many_to_one')

# %%
# Primeras filas del DataFrame con datos de delitos y población
df_mvd_group_pob.head()
# Out:
#   BARRIO_MONTEVIDEO       FECHA   AÑO  MES  DIA_MES DIA_SEMANA  SEMANA_MES  \
# 0            AGUADA  2013-01-02  2013    1        2  MIERCOLES           1
# 1            AGUADA  2013-01-03  2013    1        3     JUEVES           1
# 2            AGUADA  2013-01-04  2013    1        4    VIERNES           1
# 3            AGUADA  2013-01-05  2013    1        5     SABADO           1
# 4            AGUADA  2013-01-06  2013    1        6    DOMINGO           1
#
#           SEMESTRE TRIMESTRE  count_delitos  POBLACION  TURISTICO MUNICIPIO  \
# 0  PRIMER SEMESTRE   ENE-MAR              1      19038          0         C
# 1  PRIMER SEMESTRE   ENE-MAR              1      19038          0         C
# 2  PRIMER SEMESTRE   ENE-MAR              6      19038          0         C
# 3  PRIMER SEMESTRE   ENE-MAR              1      19038          0         C
# 4  PRIMER SEMESTRE   ENE-MAR              4      19038          0         C
#
#   PLAYA  INSE
# 0    NO     8
# 1    NO     8
# 2    NO     8
# 3    NO     8
# 4    NO     8

# %%
df_mvd_group_pob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241868 entries, 0 to 241867
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   BARRIO_MONTEVIDEO  241868 non-null  object
#  1   FECHA              241868 non-null  object
#  2   AÑO                241868 non-null  int64
#  3   MES                241868 non-null  int32
#  4   DIA_MES            241868 non-null  int32
#  5   DIA_SEMANA         241868 non-null  object
#  6   SEMANA_MES         241868 non-null  int64
#  7   SEMESTRE           241868 non-null  object
#  8   TRIMESTRE          241868 non-null  object
#  9   count_delitos      241868 non-null  int64
#  10  POBLACION          241868 non-null  int64
#  11  TURISTICO          241868 non-null  int64
#  12  MUNICIPIO          241868 non-null  object
#  13  PLAYA              241868 non-null  object
#  14  INSE               241868 non-null  int64
# dtypes: int32(2), int64(6), object(7)
# memory usage: 25.8+ MB

# %% [markdown]
# - Hay 248.447 registros, todos con su población correspondiente.

# %%
# Convertir la columna 'FECHA' a formato datetime
df_mvd_group_pob['FECHA'] = pd.to_datetime(df_mvd_group_pob['FECHA'], format='%Y-%m-%d')

# Modificamos columa fecha para que incluya solo el año, mes y dia para hacer join con datos de clima
df_mvd_group_pob['FECHA'] = df_mvd_group_pob['FECHA'].dt.strftime('%Y-%m-%d')

# %%
# Chequeando que la columna 'FECHA' haya sido modificada correctamente
df_mvd_group_pob.head()
# Out:
#   BARRIO_MONTEVIDEO       FECHA   AÑO  MES  DIA_MES DIA_SEMANA  SEMANA_MES  \
# 0            AGUADA  2013-01-02  2013    1        2  MIERCOLES           1
# 1            AGUADA  2013-01-03  2013    1        3     JUEVES           1
# 2            AGUADA  2013-01-04  2013    1        4    VIERNES           1
# 3            AGUADA  2013-01-05  2013    1        5     SABADO           1
# 4            AGUADA  2013-01-06  2013    1        6    DOMINGO           1
#
#           SEMESTRE TRIMESTRE  count_delitos  POBLACION  TURISTICO MUNICIPIO  \
# 0  PRIMER SEMESTRE   ENE-MAR              1      19038          0         C
# 1  PRIMER SEMESTRE   ENE-MAR              1      19038          0         C
# 2  PRIMER SEMESTRE   ENE-MAR              6      19038          0         C
# 3  PRIMER SEMESTRE   ENE-MAR              1      19038          0         C
# 4  PRIMER SEMESTRE   ENE-MAR              4      19038          0         C
#
#   PLAYA  INSE
# 0    NO     8
# 1    NO     8
# 2    NO     8
# 3    NO     8
# 4    NO     8

# %% [markdown]
# #### Incorporamos datos de clima obtenidos de VisualCrossing

# %%
# Cargando datos de clima
df_clima = pd.read_csv('data/ClimaVisualCrossing/montevideo_clima_glob_clean.csv', sep=',')

# %%
# Primeras filas del DataFrame de clima
df_clima.head().T
# Out:
#                                    0           1           2           3  \
# datetime                  2015-03-31  2015-04-01  2015-04-02  2015-04-03
# tempmax                         23.0        25.5        30.5        30.2
# tempmin                         16.7        11.2        12.1        14.0
# temp                            19.3        18.6        20.7        22.0
# feelslikemax                    23.0        25.5        28.7        29.5
# feelslikemin                    16.7        11.2        12.1        14.0
# feelslike                       19.3        18.6        20.4        21.8
# humidity                        80.1        69.6        54.3        54.2
# precip                           0.0         0.0         0.0         0.0
# windgust                        42.5        24.8        35.3        39.2
# windspeed                       24.1        15.8        21.5        24.2
# sealevelpressure              1013.3      1015.8      1013.4      1009.6
# visibility                      10.4         9.6        10.5        11.5
# severerisk                       0.0         0.0         0.0         0.0
# conditionClear                     0           1           1           1
# conditionPartiallyCloudy           1           0           0           0
# conditionOvercast                  0           0           0           0
# conditionRain                      0           0           0           0
# windirCat                        Sur       Norte       Norte       Norte
# fecha                     2015-03-31  2015-04-01  2015-04-02  2015-04-03
# severeriskCat                   Bajo        Bajo        Bajo        Bajo
#
#                                    4
# datetime                  2015-04-04
# tempmax                         23.8
# tempmin                         19.0
# temp                            21.3
# feelslikemax                    23.8
# feelslikemin                    19.0
# feelslike                       21.3
# humidity                        82.9
# precip                           0.3
# windgust                        34.9
# windspeed                       20.7
# sealevelpressure              1008.8
# visibility                       9.1
# severerisk                       0.0
# conditionClear                     0
# conditionPartiallyCloudy           1
# conditionOvercast                  0
# conditionRain                      1
# windirCat                        Sur
# fecha                     2015-04-04
# severeriskCat                   Bajo

# %%
# Uniendo los datasets de delitos y clima por columna 'FECHA', left join
df_mvd_group_pob_clima = df_mvd_group_pob.merge(df_clima, left_on='FECHA', right_on='fecha', how='left', suffixes=('_mvd_grup_pob', '_clima'), validate='many_to_one')

# %%
df_mvd_group_pob_clima.head().T
# Out:
#                                         0                1                2  \
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA           AGUADA
# FECHA                          2013-01-02       2013-01-03       2013-01-04
# AÑO                                  2013             2013             2013
# MES                                     1                1                1
# DIA_MES                                 2                3                4
# DIA_SEMANA                      MIERCOLES           JUEVES          VIERNES
# SEMANA_MES                              1                1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR          ENE-MAR
# count_delitos                           1                1                6
# POBLACION                           19038            19038            19038
# TURISTICO                               0                0                0
# MUNICIPIO                               C                C                C
# PLAYA                                  NO               NO               NO
# INSE                                    8                8                8
# datetime                       2013-01-02       2013-01-03       2013-01-04
# tempmax                              19.5             24.5             29.4
# tempmin                              12.9             11.0             17.1
# temp                                 17.1             18.2             23.7
# feelslikemax                         19.5             24.5             30.8
# feelslikemin                         12.9             11.0             17.1
# feelslike                            17.1             18.2             24.3
# humidity                             68.1             70.2             67.4
# precip                                0.0              0.0              0.0
# windgust                              NaN              NaN              NaN
# windspeed                            22.3             22.3             20.4
# sealevelpressure                   1020.4           1019.2           1014.7
# visibility                           11.7             11.7             11.5
# severerisk                            0.0              0.0              0.0
# conditionClear                          0                1                0
# conditionPartiallyCloudy                1                0                1
# conditionOvercast                       0                0                0
# conditionRain                           0                0                0
# windirCat                             Sur             Este             Este
# fecha                          2013-01-02       2013-01-03       2013-01-04
# severeriskCat                        Bajo             Bajo             Bajo
#
#                                         3                4
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA
# FECHA                          2013-01-05       2013-01-06
# AÑO                                  2013             2013
# MES                                     1                1
# DIA_MES                                 5                6
# DIA_SEMANA                         SABADO          DOMINGO
# SEMANA_MES                              1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR
# count_delitos                           1                4
# POBLACION                           19038            19038
# TURISTICO                               0                0
# MUNICIPIO                               C                C
# PLAYA                                  NO               NO
# INSE                                    8                8
# datetime                       2013-01-05       2013-01-06
# tempmax                              32.0             28.1
# tempmin                              19.9             20.1
# temp                                 25.5             24.5
# feelslikemax                         35.8             29.5
# feelslikemin                         19.9             20.1
# feelslike                            26.5             24.8
# humidity                             75.2             77.1
# precip                              6.583              0.0
# windgust                              NaN              NaN
# windspeed                            22.2             16.5
# sealevelpressure                   1008.3           1005.3
# visibility                           11.4             11.6
# severerisk                            0.0              0.0
# conditionClear                          0                0
# conditionPartiallyCloudy                1                1
# conditionOvercast                       0                0
# conditionRain                           1                0
# windirCat                           Norte            Oeste
# fecha                          2013-01-05       2013-01-06
# severeriskCat                        Bajo             Bajo

# %%
df_mvd_group_pob_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241868 entries, 0 to 241867
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   BARRIO_MONTEVIDEO         241868 non-null  object
#  1   FECHA                     241868 non-null  object
#  2   AÑO                       241868 non-null  int64
#  3   MES                       241868 non-null  int32
#  4   DIA_MES                   241868 non-null  int32
#  5   DIA_SEMANA                241868 non-null  object
#  6   SEMANA_MES                241868 non-null  int64
#  7   SEMESTRE                  241868 non-null  object
#  8   TRIMESTRE                 241868 non-null  object
#  9   count_delitos             241868 non-null  int64
#  10  POBLACION                 241868 non-null  int64
#  11  TURISTICO                 241868 non-null  int64
#  12  MUNICIPIO                 241868 non-null  object
#  13  PLAYA                     241868 non-null  object
#  14  INSE                      241868 non-null  int64
#  15  datetime                  241868 non-null  object
#  16  tempmax                   241868 non-null  float64
#  17  tempmin                   241868 non-null  float64
#  18  temp                      241868 non-null  float64
#  19  feelslikemax              241868 non-null  float64
#  20  feelslikemin              241868 non-null  float64
#  21  feelslike                 241868 non-null  float64
#  22  humidity                  241868 non-null  float64
#  23  precip                    241643 non-null  float64
#  24  windgust                  203640 non-null  float64
#  25  windspeed                 241868 non-null  float64
#  26  sealevelpressure          241868 non-null  float64
#  27  visibility                241868 non-null  float64
#  28  severerisk                241868 non-null  float64
#  29  conditionClear            241868 non-null  int64
#  30  conditionPartiallyCloudy  241868 non-null  int64
#  31  conditionOvercast         241868 non-null  int64
#  32  conditionRain             241868 non-null  int64
#  33  windirCat                 241868 non-null  object
#  34  fecha                     241868 non-null  object
#  35  severeriskCat             241868 non-null  object
# dtypes: float64(13), int32(2), int64(10), object(11)
# memory usage: 64.6+ MB

# %% [markdown]
# - Hay 248.447 Registros todos con sus datos de clima

# %% [markdown]
# #### Incroporacion de datos de Desempleo

# %%
# Cargamos datos de desempleo
df_desempleo = pd.read_csv('data/Desempleo_Mensual.csv')

# %%
df_desempleo.head()
# Out:
#     Ano  Mes  TasaPais  TasaMontevideo  TasaInterior
# 0  2006    1     13.20           12.34         13.84
# 1  2006    2     12.19           11.49         12.69
# 2  2006    3     11.80           12.51         11.26
# 3  2006    4     10.93           10.75         11.07
# 4  2006    5     10.52           10.43         10.59

# %%
df_desempleo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ano             225 non-null    int64
#  1   Mes             225 non-null    int64
#  2   TasaPais        225 non-null    float64
#  3   TasaMontevideo  225 non-null    float64
#  4   TasaInterior    225 non-null    float64
# dtypes: float64(3), int64(2)
# memory usage: 8.9 KB

# %%
# Eliminando columnas innecesarias, Tasa Pais y Tasa Interior
df_desempleo.drop(columns=['TasaPais','TasaInterior'], inplace=True)

# %%
# Uniendo los datasets de delitos y desempleo por columna 'AÑO' y 'MES', left join
df_mvd_group_pob_clima_des = df_mvd_group_pob_clima.merge(df_desempleo, left_on=['AÑO', 'MES'], right_on=['Ano', 'Mes'], how='left', suffixes=('_mvd_grup_pob_clima', '_desempleo'), validate='many_to_one')

# %%
# Información del DataFrame
df_mvd_group_pob_clima_des.head().T
# Out:
#                                         0                1                2  \
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA           AGUADA
# FECHA                          2013-01-02       2013-01-03       2013-01-04
# AÑO                                  2013             2013             2013
# MES                                     1                1                1
# DIA_MES                                 2                3                4
# DIA_SEMANA                      MIERCOLES           JUEVES          VIERNES
# SEMANA_MES                              1                1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR          ENE-MAR
# count_delitos                           1                1                6
# POBLACION                           19038            19038            19038
# TURISTICO                               0                0                0
# MUNICIPIO                               C                C                C
# PLAYA                                  NO               NO               NO
# INSE                                    8                8                8
# datetime                       2013-01-02       2013-01-03       2013-01-04
# tempmax                              19.5             24.5             29.4
# tempmin                              12.9             11.0             17.1
# temp                                 17.1             18.2             23.7
# feelslikemax                         19.5             24.5             30.8
# feelslikemin                         12.9             11.0             17.1
# feelslike                            17.1             18.2             24.3
# humidity                             68.1             70.2             67.4
# precip                                0.0              0.0              0.0
# windgust                              NaN              NaN              NaN
# windspeed                            22.3             22.3             20.4
# sealevelpressure                   1020.4           1019.2           1014.7
# visibility                           11.7             11.7             11.5
# severerisk                            0.0              0.0              0.0
# conditionClear                          0                1                0
# conditionPartiallyCloudy                1                0                1
# conditionOvercast                       0                0                0
# conditionRain                           0                0                0
# windirCat                             Sur             Este             Este
# fecha                          2013-01-02       2013-01-03       2013-01-04
# severeriskCat                        Bajo             Bajo             Bajo
# Ano                                  2013             2013             2013
# Mes                                     1                1                1
# TasaMontevideo                       7.64             7.64             7.64
#
#                                         3                4
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA
# FECHA                          2013-01-05       2013-01-06
# AÑO                                  2013             2013
# MES                                     1                1
# DIA_MES                                 5                6
# DIA_SEMANA                         SABADO          DOMINGO
# SEMANA_MES                              1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR
# count_delitos                           1                4
# POBLACION                           19038            19038
# TURISTICO                               0                0
# MUNICIPIO                               C                C
# PLAYA                                  NO               NO
# INSE                                    8                8
# datetime                       2013-01-05       2013-01-06
# tempmax                              32.0             28.1
# tempmin                              19.9             20.1
# temp                                 25.5             24.5
# feelslikemax                         35.8             29.5
# feelslikemin                         19.9             20.1
# feelslike                            26.5             24.8
# humidity                             75.2             77.1
# precip                              6.583              0.0
# windgust                              NaN              NaN
# windspeed                            22.2             16.5
# sealevelpressure                   1008.3           1005.3
# visibility                           11.4             11.6
# severerisk                            0.0              0.0
# conditionClear                          0                0
# conditionPartiallyCloudy                1                1
# conditionOvercast                       0                0
# conditionRain                           1                0
# windirCat                           Norte            Oeste
# fecha                          2013-01-05       2013-01-06
# severeriskCat                        Bajo             Bajo
# Ano                                  2013             2013
# Mes                                     1                1
# TasaMontevideo                       7.64             7.64

# %%
df_mvd_group_pob_clima_des.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241868 entries, 0 to 241867
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   BARRIO_MONTEVIDEO         241868 non-null  object
#  1   FECHA                     241868 non-null  object
#  2   AÑO                       241868 non-null  int64
#  3   MES                       241868 non-null  int32
#  4   DIA_MES                   241868 non-null  int32
#  5   DIA_SEMANA                241868 non-null  object
#  6   SEMANA_MES                241868 non-null  int64
#  7   SEMESTRE                  241868 non-null  object
#  8   TRIMESTRE                 241868 non-null  object
#  9   count_delitos             241868 non-null  int64
#  10  POBLACION                 241868 non-null  int64
#  11  TURISTICO                 241868 non-null  int64
#  12  MUNICIPIO                 241868 non-null  object
#  13  PLAYA                     241868 non-null  object
#  14  INSE                      241868 non-null  int64
#  15  datetime                  241868 non-null  object
#  16  tempmax                   241868 non-null  float64
#  17  tempmin                   241868 non-null  float64
#  18  temp                      241868 non-null  float64
#  19  feelslikemax              241868 non-null  float64
#  20  feelslikemin              241868 non-null  float64
#  21  feelslike                 241868 non-null  float64
#  22  humidity                  241868 non-null  float64
#  23  precip                    241643 non-null  float64
#  24  windgust                  203640 non-null  float64
#  25  windspeed                 241868 non-null  float64
#  26  sealevelpressure          241868 non-null  float64
#  27  visibility                241868 non-null  float64
#  28  severerisk                241868 non-null  float64
#  29  conditionClear            241868 non-null  int64
#  30  conditionPartiallyCloudy  241868 non-null  int64
#  31  conditionOvercast         241868 non-null  int64
#  32  conditionRain             241868 non-null  int64
#  33  windirCat                 241868 non-null  object
#  34  fecha                     241868 non-null  object
#  35  severeriskCat             241868 non-null  object
#  36  Ano                       241868 non-null  int64
#  37  Mes                       241868 non-null  int64
#  38  TasaMontevideo            241868 non-null  float64
# dtypes: float64(14), int32(2), int64(12), object(11)
# memory usage: 70.1+ MB

# %%
# Fecha, Ano y Mes están duplicadas, eliminamos una de ellas
df_mvd_group_pob_clima_des.drop(columns=['fecha', 'Ano', 'Mes', 'datetime'], inplace=True)

# %%
# Transformando todos los nombres de las variables a mayusculas
df_mvd_group_pob_clima_des.columns = df_mvd_group_pob_clima_des.columns.str.upper()

# %%
df_mvd_group_pob_clima_des.head().T
# Out:
#                                         0                1                2  \
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA           AGUADA
# FECHA                          2013-01-02       2013-01-03       2013-01-04
# AÑO                                  2013             2013             2013
# MES                                     1                1                1
# DIA_MES                                 2                3                4
# DIA_SEMANA                      MIERCOLES           JUEVES          VIERNES
# SEMANA_MES                              1                1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR          ENE-MAR
# COUNT_DELITOS                           1                1                6
# POBLACION                           19038            19038            19038
# TURISTICO                               0                0                0
# MUNICIPIO                               C                C                C
# PLAYA                                  NO               NO               NO
# INSE                                    8                8                8
# TEMPMAX                              19.5             24.5             29.4
# TEMPMIN                              12.9             11.0             17.1
# TEMP                                 17.1             18.2             23.7
# FEELSLIKEMAX                         19.5             24.5             30.8
# FEELSLIKEMIN                         12.9             11.0             17.1
# FEELSLIKE                            17.1             18.2             24.3
# HUMIDITY                             68.1             70.2             67.4
# PRECIP                                0.0              0.0              0.0
# WINDGUST                              NaN              NaN              NaN
# WINDSPEED                            22.3             22.3             20.4
# SEALEVELPRESSURE                   1020.4           1019.2           1014.7
# VISIBILITY                           11.7             11.7             11.5
# SEVERERISK                            0.0              0.0              0.0
# CONDITIONCLEAR                          0                1                0
# CONDITIONPARTIALLYCLOUDY                1                0                1
# CONDITIONOVERCAST                       0                0                0
# CONDITIONRAIN                           0                0                0
# WINDIRCAT                             Sur             Este             Este
# SEVERERISKCAT                        Bajo             Bajo             Bajo
# TASAMONTEVIDEO                       7.64             7.64             7.64
#
#                                         3                4
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA
# FECHA                          2013-01-05       2013-01-06
# AÑO                                  2013             2013
# MES                                     1                1
# DIA_MES                                 5                6
# DIA_SEMANA                         SABADO          DOMINGO
# SEMANA_MES                              1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR
# COUNT_DELITOS                           1                4
# POBLACION                           19038            19038
# TURISTICO                               0                0
# MUNICIPIO                               C                C
# PLAYA                                  NO               NO
# INSE                                    8                8
# TEMPMAX                              32.0             28.1
# TEMPMIN                              19.9             20.1
# TEMP                                 25.5             24.5
# FEELSLIKEMAX                         35.8             29.5
# FEELSLIKEMIN                         19.9             20.1
# FEELSLIKE                            26.5             24.8
# HUMIDITY                             75.2             77.1
# PRECIP                              6.583              0.0
# WINDGUST                              NaN              NaN
# WINDSPEED                            22.2             16.5
# SEALEVELPRESSURE                   1008.3           1005.3
# VISIBILITY                           11.4             11.6
# SEVERERISK                            0.0              0.0
# CONDITIONCLEAR                          0                0
# CONDITIONPARTIALLYCLOUDY                1                1
# CONDITIONOVERCAST                       0                0
# CONDITIONRAIN                           1                0
# WINDIRCAT                           Norte            Oeste
# SEVERERISKCAT                        Bajo             Bajo
# TASAMONTEVIDEO                       7.64             7.64

# %% [markdown]
# #### Incorporar datos de días festivos

# %%
# Cargamos dataset de dias fetivos
df_fest = pd.read_excel('data/festivos_uy.xlsx')

# %%
# Mostramos información del DataFrame
df_fest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dia             254 non-null    int64
#  1   Mes             254 non-null    int64
#  2   Ano             254 non-null    int64
#  3   No_Laborable    254 non-null    int64
#  4   Nombre_Festivo  254 non-null    object
# dtypes: int64(4), object(1)
# memory usage: 10.1+ KB

# %%
# Primeras filas del DataFrame
df_fest.head()
# Out:
#    Dia  Mes   Ano  No_Laborable Nombre_Festivo
# 0    1    1  2013             1       AñoNuevo
# 1    6    1  2013             0          Reyes
# 2   11    2  2013             0       Carnaval
# 3   12    2  2013             0       Carnaval
# 4   24    3  2013             0        Turismo

# %%
# Join de los DataFrame, al DataFrame anterior se le incorporan los datos de dias festivos
df_mvd_group_pob_clima_des_fest = df_mvd_group_pob_clima_des.merge(df_fest, left_on=['AÑO','MES', 'DIA_MES'], right_on=['Ano','Mes','Dia'], how='left', suffixes=('_mvd_grup_pob_clima_des', '_fest'), validate='many_to_one')

# %%
df_mvd_group_pob_clima_des_fest.head().T
# Out:
#                                         0                1                2  \
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA           AGUADA
# FECHA                          2013-01-02       2013-01-03       2013-01-04
# AÑO                                  2013             2013             2013
# MES                                     1                1                1
# DIA_MES                                 2                3                4
# DIA_SEMANA                      MIERCOLES           JUEVES          VIERNES
# SEMANA_MES                              1                1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR          ENE-MAR
# COUNT_DELITOS                           1                1                6
# POBLACION                           19038            19038            19038
# TURISTICO                               0                0                0
# MUNICIPIO                               C                C                C
# PLAYA                                  NO               NO               NO
# INSE                                    8                8                8
# TEMPMAX                              19.5             24.5             29.4
# TEMPMIN                              12.9             11.0             17.1
# TEMP                                 17.1             18.2             23.7
# FEELSLIKEMAX                         19.5             24.5             30.8
# FEELSLIKEMIN                         12.9             11.0             17.1
# FEELSLIKE                            17.1             18.2             24.3
# HUMIDITY                             68.1             70.2             67.4
# PRECIP                                0.0              0.0              0.0
# WINDGUST                              NaN              NaN              NaN
# WINDSPEED                            22.3             22.3             20.4
# SEALEVELPRESSURE                   1020.4           1019.2           1014.7
# VISIBILITY                           11.7             11.7             11.5
# SEVERERISK                            0.0              0.0              0.0
# CONDITIONCLEAR                          0                1                0
# CONDITIONPARTIALLYCLOUDY                1                0                1
# CONDITIONOVERCAST                       0                0                0
# CONDITIONRAIN                           0                0                0
# WINDIRCAT                             Sur             Este             Este
# SEVERERISKCAT                        Bajo             Bajo             Bajo
# TASAMONTEVIDEO                       7.64             7.64             7.64
# Dia                                   NaN              NaN              NaN
# Mes                                   NaN              NaN              NaN
# Ano                                   NaN              NaN              NaN
# No_Laborable                          NaN              NaN              NaN
# Nombre_Festivo                        NaN              NaN              NaN
#
#                                         3                4
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA
# FECHA                          2013-01-05       2013-01-06
# AÑO                                  2013             2013
# MES                                     1                1
# DIA_MES                                 5                6
# DIA_SEMANA                         SABADO          DOMINGO
# SEMANA_MES                              1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR
# COUNT_DELITOS                           1                4
# POBLACION                           19038            19038
# TURISTICO                               0                0
# MUNICIPIO                               C                C
# PLAYA                                  NO               NO
# INSE                                    8                8
# TEMPMAX                              32.0             28.1
# TEMPMIN                              19.9             20.1
# TEMP                                 25.5             24.5
# FEELSLIKEMAX                         35.8             29.5
# FEELSLIKEMIN                         19.9             20.1
# FEELSLIKE                            26.5             24.8
# HUMIDITY                             75.2             77.1
# PRECIP                              6.583              0.0
# WINDGUST                              NaN              NaN
# WINDSPEED                            22.2             16.5
# SEALEVELPRESSURE                   1008.3           1005.3
# VISIBILITY                           11.4             11.6
# SEVERERISK                            0.0              0.0
# CONDITIONCLEAR                          0                0
# CONDITIONPARTIALLYCLOUDY                1                1
# CONDITIONOVERCAST                       0                0
# CONDITIONRAIN                           1                0
# WINDIRCAT                           Norte            Oeste
# SEVERERISKCAT                        Bajo             Bajo
# TASAMONTEVIDEO                       7.64             7.64
# Dia                                   NaN              6.0
# Mes                                   NaN              1.0
# Ano                                   NaN           2013.0
# No_Laborable                          NaN              0.0
# Nombre_Festivo                        NaN            Reyes

# %%
# Eliminamos columnas innecesarias provenientes del DataFrame de días festivos
df_mvd_group_pob_clima_des_fest.drop(columns=['Ano', 'Mes', 'Dia'], inplace=True)

# %% [markdown]
# #### Normalizar cuenta de delitos y DF final

# %%
# Creando nueva columna COUNT_DELITOS_NORM que es la cantidad de delitos por cada 1000 habitantes por dia y barrio

df_mvd_group_pob_clima_des_fest['COUNT_DELITOS_NORM'] = df_mvd_group_pob_clima_des_fest['COUNT_DELITOS'] * 1000 / df_mvd_group_pob_clima_des_fest['POBLACION']

# %%
# Describiendo la nueva variable COUNT_DELITOS_NORM 
df_mvd_group_pob_clima_des_fest['COUNT_DELITOS_NORM'].describe()
# Out:
# count    241868.000000
# mean          0.185950
# std           0.115605
# min           0.014470
# 25%           0.101292
# 50%           0.157580
# 75%           0.243368
# max           3.294118
# Name: COUNT_DELITOS_NORM, dtype: float64

# %%
# Calculando en percntil 60% de la variable COUNT_DELITOS_NORM
np.percentile(df_mvd_group_pob_clima_des_fest['COUNT_DELITOS_NORM'], 60)
# Out:
# np.float64(0.19238168526356292)

# %%
# Histograma de count_delitos_norm
plt.figure(figsize=(15, 5))
sns.histplot(data=df_mvd_group_pob_clima_des_fest, x='COUNT_DELITOS_NORM', bins=60, color='Yellow')
plt.show()

# %% [markdown]
# #### Asignar etiqueta Bajo o Alto riesgo de delito
#
# - Si el valor de COUNT_DELITOS_NORM es mayor a percentil 75 , se asigna Alto riesgo

# %%
# Asignando la etiqueta 'Alto' o 'Bajo' riesgo a la variable 'RIESGO' en función de un límite predefinido

limite = 0.243368 # 75 percentil, modificar según queramos definir el riesgo

# Funcion para asignar riesgo

def asignar_riesgo(count_delitos_norm):
    if count_delitos_norm > limite:
        return 'Alto'
    else:
        return 'Bajo'
    
# Aplicar función asignar_riesgo a la columna 'COUNT_DELITOS_NORM'
df_mvd_group_pob_clima_des_fest['RIESGO'] = df_mvd_group_pob_clima_des_fest['COUNT_DELITOS_NORM'].apply(asignar_riesgo)

# %%
df_mvd_group_pob_clima_des_fest.head().T
# Out:
#                                         0                1                2  \
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA           AGUADA
# FECHA                          2013-01-02       2013-01-03       2013-01-04
# AÑO                                  2013             2013             2013
# MES                                     1                1                1
# DIA_MES                                 2                3                4
# DIA_SEMANA                      MIERCOLES           JUEVES          VIERNES
# SEMANA_MES                              1                1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR          ENE-MAR
# COUNT_DELITOS                           1                1                6
# POBLACION                           19038            19038            19038
# TURISTICO                               0                0                0
# MUNICIPIO                               C                C                C
# PLAYA                                  NO               NO               NO
# INSE                                    8                8                8
# TEMPMAX                              19.5             24.5             29.4
# TEMPMIN                              12.9             11.0             17.1
# TEMP                                 17.1             18.2             23.7
# FEELSLIKEMAX                         19.5             24.5             30.8
# FEELSLIKEMIN                         12.9             11.0             17.1
# FEELSLIKE                            17.1             18.2             24.3
# HUMIDITY                             68.1             70.2             67.4
# PRECIP                                0.0              0.0              0.0
# WINDGUST                              NaN              NaN              NaN
# WINDSPEED                            22.3             22.3             20.4
# SEALEVELPRESSURE                   1020.4           1019.2           1014.7
# VISIBILITY                           11.7             11.7             11.5
# SEVERERISK                            0.0              0.0              0.0
# CONDITIONCLEAR                          0                1                0
# CONDITIONPARTIALLYCLOUDY                1                0                1
# CONDITIONOVERCAST                       0                0                0
# CONDITIONRAIN                           0                0                0
# WINDIRCAT                             Sur             Este             Este
# SEVERERISKCAT                        Bajo             Bajo             Bajo
# TASAMONTEVIDEO                       7.64             7.64             7.64
# No_Laborable                          NaN              NaN              NaN
# Nombre_Festivo                        NaN              NaN              NaN
# COUNT_DELITOS_NORM               0.052527         0.052527         0.315159
# RIESGO                               Bajo             Bajo             Alto
#
#                                         3                4
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA
# FECHA                          2013-01-05       2013-01-06
# AÑO                                  2013             2013
# MES                                     1                1
# DIA_MES                                 5                6
# DIA_SEMANA                         SABADO          DOMINGO
# SEMANA_MES                              1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR
# COUNT_DELITOS                           1                4
# POBLACION                           19038            19038
# TURISTICO                               0                0
# MUNICIPIO                               C                C
# PLAYA                                  NO               NO
# INSE                                    8                8
# TEMPMAX                              32.0             28.1
# TEMPMIN                              19.9             20.1
# TEMP                                 25.5             24.5
# FEELSLIKEMAX                         35.8             29.5
# FEELSLIKEMIN                         19.9             20.1
# FEELSLIKE                            26.5             24.8
# HUMIDITY                             75.2             77.1
# PRECIP                              6.583              0.0
# WINDGUST                              NaN              NaN
# WINDSPEED                            22.2             16.5
# SEALEVELPRESSURE                   1008.3           1005.3
# VISIBILITY                           11.4             11.6
# SEVERERISK                            0.0              0.0
# CONDITIONCLEAR                          0                0
# CONDITIONPARTIALLYCLOUDY                1                1
# CONDITIONOVERCAST                       0                0
# CONDITIONRAIN                           1                0
# WINDIRCAT                           Norte            Oeste
# SEVERERISKCAT                        Bajo             Bajo
# TASAMONTEVIDEO                       7.64             7.64
# No_Laborable                          NaN              0.0
# Nombre_Festivo                        NaN            Reyes
# COUNT_DELITOS_NORM               0.052527         0.210106
# RIESGO                               Bajo             Bajo

# %%
# Contando la cantidad de registros por riesgo
df_mvd_group_pob_clima_des_fest['RIESGO'].value_counts()
# Out:
# RIESGO
# Bajo    181195
# Alto     60673
# Name: count, dtype: int64

# %% [markdown]
# - Aproximadamente 1/4 de los datos son de alto riesgo

# %%
# Transformando nombre de variables a mayusculas
df_mvd_group_pob_clima_des_fest.columns = df_mvd_group_pob_clima_des_fest.columns.str.upper()

# %%
# contamos valores perdidios
df_mvd_group_pob_clima_des_fest.isnull().sum().sort_values(ascending=False)
# Out:
# NOMBRE_FESTIVO              228022
# NO_LABORABLE                228022
# WINDGUST                     38228
# PRECIP                         225
# BARRIO_MONTEVIDEO                0
# FECHA                            0
# AÑO                              0
# SEMANA_MES                       0
# DIA_SEMANA                       0
# DIA_MES                          0
# MES                              0
# TURISTICO                        0
# SEMESTRE                         0
# COUNT_DELITOS                    0
# TRIMESTRE                        0
# INSE                             0
# TEMPMAX                          0
# TEMP                             0
# TEMPMIN                          0
# FEELSLIKEMAX                     0
# MUNICIPIO                        0
# PLAYA                            0
# POBLACION                        0
# HUMIDITY                         0
# FEELSLIKE                        0
# FEELSLIKEMIN                     0
# WINDSPEED                        0
# SEVERERISK                       0
# CONDITIONCLEAR                   0
# SEALEVELPRESSURE                 0
# VISIBILITY                       0
# CONDITIONOVERCAST                0
# CONDITIONPARTIALLYCLOUDY         0
# CONDITIONRAIN                    0
# WINDIRCAT                        0
# TASAMONTEVIDEO                   0
# SEVERERISKCAT                    0
# COUNT_DELITOS_NORM               0
# RIESGO                           0
# dtype: int64

# %%
# Asignamos categoría a datos perdidos de la columna 'NO_LABORABLE'
df_mvd_group_pob_clima_des_fest['NO_LABORABLE'] = df_mvd_group_pob_clima_des_fest['NO_LABORABLE'].fillna('999')

# Asignamos categoría a datos perdidos de la columna 'NOMBRE_FESTIVO'
df_mvd_group_pob_clima_des_fest['NOMBRE_FESTIVO'] = df_mvd_group_pob_clima_des_fest['NOMBRE_FESTIVO'].fillna('NC')

# Eliminamos datos perdidos en la columna PRECIP
df_mvd_group_pob_clima_des_fest.dropna(subset=['PRECIP'], inplace=True)

# Windgust queda con los valores perdidos

# Renombramos columna TASAMONTEVIDEO
df_mvd_group_pob_clima_des_fest.rename(columns={'TASAMONTEVIDEO':'TASA_DESEMPLEO'})
# Out:
#           BARRIO_MONTEVIDEO       FECHA   AÑO  MES  DIA_MES DIA_SEMANA  \
# 0                    AGUADA  2013-01-02  2013    1        2  MIERCOLES
# 1                    AGUADA  2013-01-03  2013    1        3     JUEVES
# 2                    AGUADA  2013-01-04  2013    1        4    VIERNES
# 3                    AGUADA  2013-01-05  2013    1        5     SABADO
# 4                    AGUADA  2013-01-06  2013    1        6    DOMINGO
# ...                     ...         ...   ...  ...      ...        ...
# 241863  VILLA MUÑOZ, RETIRO  2024-09-26  2024    9       26     JUEVES
# 241864  VILLA MUÑOZ, RETIRO  2024-09-27  2024    9       27    VIERNES
# 241865  VILLA MUÑOZ, RETIRO  2024-09-28  2024    9       28     SABADO
# 241866  VILLA MUÑOZ, RETIRO  2024-09-29  2024    9       29    DOMINGO
# 241867  VILLA MUÑOZ, RETIRO  2024-09-30  2024    9       30      LUNES
#
#         SEMANA_MES          SEMESTRE TRIMESTRE  COUNT_DELITOS  ...  \
# 0                1   PRIMER SEMESTRE   ENE-MAR              1  ...
# 1                1   PRIMER SEMESTRE   ENE-MAR              1  ...
# 2                1   PRIMER SEMESTRE   ENE-MAR              6  ...
# 3                1   PRIMER SEMESTRE   ENE-MAR              1  ...
# 4                1   PRIMER SEMESTRE   ENE-MAR              4  ...
# ...            ...               ...       ...            ...  ...
# 241863           4  SEGUNDO SEMESTRE   JUL-SET              3  ...
# 241864           4  SEGUNDO SEMESTRE   JUL-SET              3  ...
# 241865           5  SEGUNDO SEMESTRE   JUL-SET              2  ...
# 241866           5  SEGUNDO SEMESTRE   JUL-SET              3  ...
# 241867           5  SEGUNDO SEMESTRE   JUL-SET              4  ...
#
#         CONDITIONPARTIALLYCLOUDY  CONDITIONOVERCAST CONDITIONRAIN WINDIRCAT  \
# 0                              1                  0             0       Sur
# 1                              0                  0             0      Este
# 2                              1                  0             0      Este
# 3                              1                  0             1     Norte
# 4                              1                  0             0     Oeste
# ...                          ...                ...           ...       ...
# 241863                         1                  0             1       Sur
# 241864                         1                  0             1      Este
# 241865                         1                  0             0     Norte
# 241866                         1                  0             0     Norte
# 241867                         1                  0             1     Norte
#
#         SEVERERISKCAT  TASA_DESEMPLEO  NO_LABORABLE  NOMBRE_FESTIVO  \
# 0                Bajo            7.64           999              NC
# 1                Bajo            7.64           999              NC
# 2                Bajo            7.64           999              NC
# 3                Bajo            7.64           999              NC
# 4                Bajo            7.64           0.0           Reyes
# ...               ...             ...           ...             ...
# 241863           Bajo            7.33           999              NC
# 241864           Bajo            7.33           999              NC
# 241865           Bajo            7.33           999              NC
# 241866           Bajo            7.33           999              NC
# 241867           Bajo            7.33           999              NC
#
#         COUNT_DELITOS_NORM  RIESGO
# 0                 0.052527    Bajo
# 1                 0.052527    Bajo
# 2                 0.315159    Alto
# 3                 0.052527    Bajo
# 4                 0.210106    Bajo
# ...                    ...     ...
# 241863            0.229095    Bajo
# 241864            0.229095    Bajo
# 241865            0.152730    Bajo
# 241866            0.229095    Bajo
# 241867            0.305460    Alto
#
# [241643 rows x 39 columns]

# %%
# Renombramos columna TASAMONTEVIDEO
df_mvd_group_pob_clima_des_fest.rename(columns={'TASAMONTEVIDEO':'TASA_DESEMPLEO'}, inplace=True)

# %%
# Se exporta el dataset a un archivo csv para su posterior uso
df_mvd_group_pob_clima_des_fest.to_csv('data/delitos_mvd_final_sin_vd.csv', index=False)
