# %% [markdown]
# ### CRÍMENES MONTEVIDEO

# %% [markdown]
# #### 0. DICIONARIO DE DATOS
# #### Variables Geográficas y Temporales
# - **`BARRIO_MONTEVIDEO`**: Nombre del barrio de Montevideo donde se registró el dato. _Tipo de dato_: Categórica. _Ejemplo_: `Pocitos`, `Ciudad Vieja`.
# - **`POBLACION`**: Cantidad de población en el barrio correspondiente. _Tipo de dato_: Numérico (entero). _Ejemplo_: `5000`, `25000`.
# - **`TURISTICO`**: Indica si el barrio es turístico. _Tipo de dato_: Binario (`1`=Sí, `0`=No). _Ejemplo_: `1`, `0`.
# - **`FECHA`**: Fecha completa del registro. _Tipo de dato_: Fecha. _Formato_: `AAAA-MM-DD`. _Ejemplo_: `2023-01-01`.
# - **`AÑO`**: Año del registro. _Tipo de dato_: Numérico (entero). _Ejemplo_: `2023`.
# - **`MES`**: Número del mes en el que ocurrió el evento. _Tipo de dato_: Numérico (entero). _Ejemplo_: `1` (Enero), `12` (Diciembre).
# - **`DIA_MES`**: Día del mes en el que ocurrió el evento. _Tipo de dato_: Numérico (entero). _Ejemplo_: `1`, `15`, `31`.
# - **`DIA_SEMANA`**: Nombre del día de la semana. _Tipo de dato_: Categórica. _Ejemplo_: `Lunes`, `Martes`.
# - **`SEMANA_MES`**: Número de la semana dentro del mes. _Tipo de dato_: Numérico (entero). _Ejemplo_: `1`, `2`, `3`.
# - **`SEMESTRE`**: Número del semestre del año. _Tipo de dato_: Numérico (entero). _Ejemplo_: `1` (Primer Semestre), `2` (Segundo Semestre).
# - **`TRIMESTRE`**: Número del trimestre del año. _Tipo de dato_: Numérico (entero). _Ejemplo_: `1`, `2`, `3`.
#
# #### Variables Climáticas
# - **`TEMPMAX`**: Temperatura máxima registrada en el día (en °C). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `25.5`, `30.1`.
# - **`TEMPMIN`**: Temperatura mínima registrada en el día (en °C). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `15.2`, `18.0`.
# - **`TEMP`**: Temperatura promedio registrada en el día (en °C). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `20.3`, `22.8`.
# - **`FEELSLIKEMAX`**: Sensación térmica máxima registrada en el día (en °C). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `28.5`, `35.0`.
# - **`FEELSLIKEMIN`**: Sensación térmica mínima registrada en el día (en °C). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `12.5`, `15.0`.
# - **`FEELSLIKE`**: Sensación térmica promedio registrada en el día (en °C). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `20.0`, `24.0`.
# - **`HUMIDITY`**: Humedad promedio en el día (en %). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `60`, `85`.
# - **`PRECIP`**: Volumen de lluvia registrado en el día (en mm). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `0.0`, `12.5`, `50.0`.
# - **`WINDGUST`**: Velocidad máxima de las rachas de viento (en km/h). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `30.0`, `50.0`.
# - **`WINDSPEED`**: Velocidad promedio del viento durante el día (en km/h). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `10.5`, `20.0`.
# - **`SEALEVELPRESSURE`**: Presión atmosférica promedio registrada en el día (en mbar). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `1013`, `1018`.
# - **`VISIBILITY`**: Visibilidad promedio en el día (en km). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `10.0`, `5.0`.
# - **`SEVERERISK`**: Nivel de alerta por riesgo severo en una escala de 0 a 100. _Tipo de dato_: Numérico (entero). _Ejemplo_: `15` (bajo), `85` (alto).
# - **`SEVERERISKCAT`**: Categoría del riesgo severo según el nivel (`Bajo`, `Medio`, `Alto`). _Tipo de dato_: Categórica. _Ejemplo_: `Bajo`, `Medio`, `Alto`.
# - **`CONDITIONCLEAR`**: Indica si el día fue despejado. _Tipo de dato_: Binario (`1`=Sí, `0`=No). _Ejemplo_: `1`, `0`.
# - **`CONDITIONPARTIALLYCLOUDY`**: Indica si el día fue parcialmente nublado. _Tipo de dato_: Binario (`1`=Sí, `0`=No). _Ejemplo_: `1`, `0`.
# - **`CONDITIONOVERCAST`**: Indica si el día fue totalmente cubierto. _Tipo de dato_: Binario (`1`=Sí, `0`=No). _Ejemplo_: `1`, `0`.
# - **`CONDITIONRAIN`**: Indica si el día fue lluvioso. _Tipo de dato_: Binario (`1`=Sí, `0`=No). _Ejemplo_: `1`, `0`.
# - **`WINDIRCAT`**: Dirección del viento categorizada. _Tipo de dato_: Categórica. _Ejemplo_: `N`, `S`, `E`, `O`.
#
# #### Variables Económicas y Sociales
# - **`TASA_DESEMPLEO`**: Nivel de desempleo en Montevideo durante el período (en %). _Tipo de dato_: Numérico (flotante). _Ejemplo_: `7.5`, `10.2`.
#
# #### Variables de Festivos
# - **`NO_LABORABLE`**: Indica si el día es feriado no laborable. _Tipo de dato_: Categórica (`1`=Sí, `0`=No, `999`=No corresponde). _Ejemplo_: `1`, `0`, `999`.
# - **`NOMBRE_FESTIVO`**: Nombre del día festivo si corresponde. _Tipo de dato_: Categórica. _Ejemplo_: `Año Nuevo`, `Navidad`.
#
# #### Variables de Crímenes
# - **`COUNT_DELITOS`**: Cantidad de delitos denunciados en la agrupación correspondiente. _Tipo de dato_: Numérico (entero). _Ejemplo_: `0`, `15`, `50`.
# - **`COUNT_DELITOS_NORM`**: Cantidad de delitos normalizada por la población del barrio. _Tipo de dato_: Numérico (flotante). _Ejemplo_: `0.5`, `2.8`, `15.0`.
# - **`RIESGO`**: **Variable objetivo** que clasifica el riesgo de delito en una agrupación. _Tipo de dato_: Categórica. _Ejemplo_: `Bajo`, `Alto`.

# %% [markdown]
# #### 1. CARGA DE DATOS

# %%
# Cargamos librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Cargamos el dataset de delitos en mvd previamente procesado
df = pd.read_csv('../../Data/processed/delitos_mvd_final_1_perc60.csv')

# %%
# Mostramos la cantidad de registros y columnas del dataset
df.shape
# Out:
# (248214, 39)

# %%
# Mostramos las primeras filas del dataset
df.head().T
# Out:
#                                         0                1                2  \
# BARRIO_MONTEVIDEO                  AGUADA           AGUADA           AGUADA
# FECHA                          2013-01-01       2013-01-02       2013-01-03
# AÑO                                  2013             2013             2013
# MES                                     1                1                1
# DIA_MES                                 1                2                3
# DIA_SEMANA                         MARTES        MIERCOLES           JUEVES
# SEMANA_MES                              1                1                1
# SEMESTRE                  PRIMER SEMESTRE  PRIMER SEMESTRE  PRIMER SEMESTRE
# TRIMESTRE                         ENE-MAR          ENE-MAR          ENE-MAR
# COUNT_DELITOS                           2                1                1
# POBLACION                           19038            19038            19038
# ...

# %%
# Chequeamos si hay datos perdidos
df.isnull().sum()
# Out:
# BARRIO_MONTEVIDEO               0
# FECHA                           0
# AÑO                             0
# MES                             0
# DIA_MES                         0
# DIA_SEMANA                      0
# SEMANA_MES                      0
# SEMESTRE                        0
# TRIMESTRE                       0
# COUNT_DELITOS                   0
# POBLACION                       0
# TURISTICO                       0
# MUNICIPIO                       0
# PLAYA                           0
# INSE                            0
# TEMPMAX                         0
# TEMPMIN                         0
# TEMP                            0
# FEELSLIKEMAX                    0
# FEELSLIKEMIN                    0
# FEELSLIKE                       0
# HUMIDITY                        0
# PRECIP                          0
# WINDGUST                    39286
# WINDSPEED                       0
# SEALEVELPRESSURE                0
# VISIBILITY                      0
# ...

# %% [markdown]
# - Variable WINDGUST también tiene datos perdidos

# %%
# Tamaño del datastet
df.shape
# Out:
# (248214, 39)

# %%
# Info del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248214 entries, 0 to 248213
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   BARRIO_MONTEVIDEO         248214 non-null  object
#  1   FECHA                     248214 non-null  object
#  2   AÑO                       248214 non-null  int64
#  3   MES                       248214 non-null  int64
#  4   DIA_MES                   248214 non-null  int64
#  5   DIA_SEMANA                248214 non-null  object
#  6   SEMANA_MES                248214 non-null  int64
#  7   SEMESTRE                  248214 non-null  object
#  8   TRIMESTRE                 248214 non-null  object
#  9   COUNT_DELITOS             248214 non-null  int64
#  10  POBLACION                 248214 non-null  int64
#  11  TURISTICO                 248214 non-null  int64
#  12  MUNICIPIO                 248214 non-null  object
# ...

# %% [markdown]
# - Tenemos 248.214 registros

# %% [markdown]
# ##### 2. ANÁLISIS EXPLORATORIO DE DATOS

# %%
# Mostramos las columnas del dataset
df.columns
# Out:
# Index(['BARRIO_MONTEVIDEO', 'FECHA', 'AÑO', 'MES', 'DIA_MES', 'DIA_SEMANA',
#        'SEMANA_MES', 'SEMESTRE', 'TRIMESTRE', 'COUNT_DELITOS', 'POBLACION',
#        'TURISTICO', 'MUNICIPIO', 'PLAYA', 'INSE', 'TEMPMAX', 'TEMPMIN', 'TEMP',
#        'FEELSLIKEMAX', 'FEELSLIKEMIN', 'FEELSLIKE', 'HUMIDITY', 'PRECIP',
#        'WINDGUST', 'WINDSPEED', 'SEALEVELPRESSURE', 'VISIBILITY', 'SEVERERISK',
#        'CONDITIONCLEAR', 'CONDITIONPARTIALLYCLOUDY', 'CONDITIONOVERCAST',
#        'CONDITIONRAIN', 'WINDIRCAT', 'SEVERERISKCAT', 'TASA_DESEMPLEO',
#        'NO_LABORABLE', 'NOMBRE_FESTIVO', 'COUNT_DELITOS_NORM', 'RIESGO'],
#       dtype='object')

# %%
# Creamos listas de variables categóricas y numéricas

# Barrio es una variable categórica pero queda fuera porque tiene 62 categorías la analizamos aparte

cat_features = ['MES', 'DIA_MES', 'DIA_SEMANA', 'SEMANA_MES', 'SEMESTRE', 'TRIMESTRE', 'TURISTICO', 'CONDITIONCLEAR', 'CONDITIONPARTIALLYCLOUDY', 'CONDITIONOVERCAST', 'CONDITIONRAIN', 'WINDIRCAT', 'NO_LABORABLE','NOMBRE_FESTIVO', 'SEVERERISKCAT', 'TURISTICO', 'MUNICIPIO', 'PLAYA', 'INSE']

num_features = ['TEMPMAX', 'TEMPMIN', 'TEMP', 'FEELSLIKEMAX','FEELSLIKEMIN', 'FEELSLIKE', 'HUMIDITY', 'PRECIP', 'WINDGUST', 'WINDSPEED', 'SEALEVELPRESSURE', 'VISIBILITY', 'SEVERERISK','TASA_DESEMPLEO','POBLACION']

# %% [markdown]
# #### 2.1. ANÁLISIS UNIVARIADO

# %% [markdown]
# ##### 2.1.1. VARIABLES CATEGÓRICAS

# %%
# Gráfico de población por barrio

# Agrupamos por barrio y quedamos con el primer valor de población ya que es siempre la misma para cada barrio
df_poblacion_barrio = df.groupby('BARRIO_MONTEVIDEO',as_index=False)['POBLACION'].first()

# Grafico de poblacion por barrrio
plt.figure(figsize=(15, 15))
sns.barplot(x='POBLACION', y='BARRIO_MONTEVIDEO', data=df_poblacion_barrio.sort_values('POBLACION', ascending=False))
plt.title('Población por barrio')
plt.xlabel('Población')
plt.ylabel('Barrio')
plt.show()

# %% [markdown]
# - Hay grandes diferencias en la densidad de población entre barrios

# %% [markdown]
# ##### 2.1.1. VARIABLES CONTÍNUAS

# %%
# Distribución de variables contínuas

plt.figure(figsize = (15, 20))
plt.suptitle("Distribución de Variables Contínuas", y=1.01, fontsize=14)

# Creamos un dataframe con las variables contínuas
df_filtered = df[num_features].copy()

# Graficamos la distribución de todas las variables
n_cols = len(df_filtered.columns)
n_rows = (n_cols + 1) // 2
for i, j in enumerate(df_filtered.columns):
    plt.subplot(n_rows, 3, i+1)
    sns.histplot(x = j, data = df_filtered,
                stat = 'density',  kde = True, bins = 30,
                color = '#04BF9D', fill = False)
plt.tight_layout()
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# - La mayoría de las variables de clima tienen curvas con tendencia normal  al igual q la tasa de desempleo.
# - Severerisk tiene la mayoría de sus datos en 0.

# %%
# Boxplot de variables contínuas

plt.figure(figsize = (15, 20))
plt.suptitle("Boxplot de Variables Contínuas", y=1.01, fontsize=14)

# Creamos un dataframe con las variables contínuas
df_filtered = df[num_features].copy()

# Graficamos la distribución de todas las variables
n_cols = len(df_filtered.columns)
n_rows = (n_cols + 1) // 2
for i, j in enumerate(df_filtered.columns):
    plt.subplot(n_rows, 3, i+1)
    sns.boxplot(x = j, data = df_filtered,
                color = '#04BF9D')
plt.tight_layout()
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# - Hay varios outliers esperados en las variables de clima, principalmente en precipitaciones, windgust, windspeed y visibility

# %% [markdown]
# #### 2.2. ANÁLISIS BIVARIADO

# %% [markdown]
# ##### 2.2.1. VARIABLES CATEGÓRICAS

# %%
# Grafico de Frecuencia registros por tipo de riesgo y barrio

# Ordenar los barrios según la cantidad de delitos de alto riesgo de menos a más
orden_barrio = df[df['RIESGO'] == 'Alto']['BARRIO_MONTEVIDEO'].value_counts(ascending=True).index

# Crear el gráfico con el orden personalizado
plt.figure(figsize=(10, 20))
sns.countplot(
    y='BARRIO_MONTEVIDEO',
    hue='RIESGO',
    data=df,
    order=orden_barrio
)
plt.title('Frecuencia de registros por tipo de riesgo y barrio')
plt.show()

# %% [markdown]
# - Hay muchas diferencias entre los barrios, esta variable va a ser importante.
# - No hay una tendencia a que los barrios con mayor frecuencia de alto riesgo sean los de menor poder adquisitivo
# - Hay algunos Barrios que tienen muy poca frecuencia de alto riesgo como: Pocitos, es justamente uno de los barrios mas densamente poblados
# - Unión es otro de los barrios más densamente poblados pero que tiene la mayor frecuencia de alto riesgo de delitos

# %%
# Gráfico de Porcentaje de distribucion de riesgo por variable categorica

# Eliminamos la variable Ba

# Create a grid with enough rows and 2 columns for the crosstab analysis
fig, axes = plt.subplots(nrows=(len(cat_features) // 2 + 1), ncols=2, figsize=(16, 40))
axes = axes.flatten()  # Flatten axes for easy indexing

palette_name = "YlGnBu"  # Select a palette

# Loop through the categorical variables
for i, col in enumerate(cat_features):
    # Compute the crosstab (percentage within each category)
    crosstab_data = pd.crosstab(df[col], df['RIESGO'], normalize='index') * 100

    # Generate colors based on the number of columns in crosstab_data
    colors = sns.color_palette(palette_name, n_colors=len(crosstab_data.columns))

    # Plot the stacked bar chart
    crosstab_data.plot(kind='bar', stacked=True, ax=axes[i], color=colors)
    axes[i].set_title(f"{col} vs. RIESGO", fontsize=18)
    axes[i].set_ylabel("Percentage (%)", fontsize=14)
    axes[i].set_xlabel(col, fontsize=14)
    axes[i].tick_params(axis='x', rotation=45, labelsize=10)
    axes[i].tick_params(axis='y', labelsize=14)

# Remove unused subplots
for j in range(len(cat_features), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
fig.suptitle("Porcentaje de Distribución de Riesgo por Variables Categóricas", fontsize=20, y=1.02)
plt.show()

# %% [markdown]
# - En general no hay grandes diferencias en la proporción de alto y bajo riesgo en las variables categóricas observando los valores para todos los barrios.
# - Hay un pequeño pico de alto riesgo en febrero y marzo y una bajada mínima en junio y julio.
# - Si el feriado es No laborable hay una pequeña disminucion del porcentaje de riesgo alto
# - Hay unas diferencias mayores en cuanto al feriado, los feriado por asuncion presidencial hay una mayor proporcion de riesgo alto y los feriados de Navidad una menor proporcion de riesgo alto.

# %% [markdown]
# Análisis de variables categóricas por barrio

# %%
# Gráfico de Porcentaje de distribucion de riesgo por variable categorica para barrio CENTRO

# Creamos subset de barrio CENTRO
df_sel = df[df['BARRIO_MONTEVIDEO'] == 'CENTRO']

# Create a grid with enough rows and 2 columns for the crosstab analysis
fig, axes = plt.subplots(nrows=(len(cat_features) // 2 + 1), ncols=2, figsize=(16, 40))
axes = axes.flatten()  # Flatten axes for easy indexing

palette_name = "YlGnBu"  # Select a palette

# Loop through the categorical variables
for i, col in enumerate(cat_features):

    # Compute the crosstab (percentage within each category)
    crosstab_data = pd.crosstab(df_sel[col], df['RIESGO'], normalize='index') * 100

    # Generate colors based on the number of columns in crosstab_data
    colors = sns.color_palette(palette_name, n_colors=len(crosstab_data.columns))

    # Plot the stacked bar chart
    crosstab_data.plot(kind='bar', stacked=True, ax=axes[i], color=colors)
    axes[i].set_title(f"{col} vs. RIESGO", fontsize=18)
    axes[i].set_ylabel("Percentage (%)", fontsize=14)
    axes[i].set_xlabel(col, fontsize=14)
    axes[i].tick_params(axis='x', rotation=45, labelsize=10)
    axes[i].tick_params(axis='y', labelsize=14)

# Remove unused subplots
for j in range(len(cat_features), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
fig.suptitle("BARRIO CENTRO - Porcentaje de Distribución de Riesgo por Variables Categóricas", fontsize=20, y=1.02)
plt.show()

# %%
# Gráfico de Porcentaje de distribucion de riesgo por variable categorica para barrio PUNTA CARRETAS

# Creamos subset de barrio PUNTA CARRETAS
df_sel = df[df['BARRIO_MONTEVIDEO'] == 'PUNTA CARRETAS']

# Create a grid with enough rows and 2 columns for the crosstab analysis
fig, axes = plt.subplots(nrows=(len(cat_features) // 2 + 1), ncols=2, figsize=(16, 40))
axes = axes.flatten()  # Flatten axes for easy indexing

palette_name = "YlGnBu"  # Select a palette

# Loop through the categorical variables
for i, col in enumerate(cat_features):

    # Compute the crosstab (percentage within each category)
    crosstab_data = pd.crosstab(df_sel[col], df['RIESGO'], normalize='index') * 100

    # Generate colors based on the number of columns in crosstab_data
    colors = sns.color_palette(palette_name, n_colors=len(crosstab_data.columns))

    # Plot the stacked bar chart
    crosstab_data.plot(kind='bar', stacked=True, ax=axes[i], color=colors)
    axes[i].set_title(f"{col} vs. RIESGO", fontsize=18)
    axes[i].set_ylabel("Percentage (%)", fontsize=14)
    axes[i].set_xlabel(col, fontsize=14)
    axes[i].tick_params(axis='x', rotation=45, labelsize=14)
    axes[i].tick_params(axis='y', labelsize=10)

# Remove unused subplots
for j in range(len(cat_features), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
fig.suptitle("BARRIO PUNTA CARRETAS - Porcentaje de Distribución de Riesgo por Variables Categóricas", fontsize=20, y=1.02)
plt.show()

# %%
# Gráfico de Porcentaje de distribucion de riesgo por variable categorica para barrio CARRASCO

# Creamos subset de barrio
df_sel = df[df['BARRIO_MONTEVIDEO'] == 'CARRASCO']

# Create a grid with enough rows and 2 columns for the crosstab analysis
fig, axes = plt.subplots(nrows=(len(cat_features) // 2 + 1), ncols=2, figsize=(16, 40))
axes = axes.flatten()  # Flatten axes for easy indexing

palette_name = "YlGnBu"  # Select a palette

# Loop through the categorical variables
for i, col in enumerate(cat_features):

    # Compute the crosstab (percentage within each category)
    crosstab_data = pd.crosstab(df_sel[col], df['RIESGO'], normalize='index') * 100

    # Generate colors based on the number of columns in crosstab_data
    colors = sns.color_palette(palette_name, n_colors=len(crosstab_data.columns))

    # Plot the stacked bar chart
    crosstab_data.plot(kind='bar', stacked=True, ax=axes[i], color=colors)
    axes[i].set_title(f"{col} vs. RIESGO", fontsize=18)
    axes[i].set_ylabel("Percentage (%)", fontsize=14)
    axes[i].set_xlabel(col, fontsize=14)
    axes[i].tick_params(axis='x', rotation=45, labelsize=10)
    axes[i].tick_params(axis='y', labelsize=14)

# Remove unused subplots
for j in range(len(cat_features), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
fig.suptitle("BARRIO CARRASCO - Porcentaje de Distribución de Riesgo por Variables Categóricas", fontsize=20, y=1.02)
plt.show()

# %%
# Gráfico de Porcentaje de distribucion de riesgo por variable categorica para barrio CASAVALLE

# Creamos subset de barrio
df_sel = df[df['BARRIO_MONTEVIDEO'] == 'CASAVALLE']

# Create a grid with enough rows and 2 columns for the crosstab analysis
fig, axes = plt.subplots(nrows=(len(cat_features) // 2 + 1), ncols=2, figsize=(16, 40))
axes = axes.flatten()  # Flatten axes for easy indexing

palette_name = "YlGnBu"  # Select a palette

# Loop through the categorical variables
for i, col in enumerate(cat_features):

    # Compute the crosstab (percentage within each category)
    crosstab_data = pd.crosstab(df_sel[col], df['RIESGO'], normalize='index') * 100

    # Generate colors based on the number of columns in crosstab_data
    colors = sns.color_palette(palette_name, n_colors=len(crosstab_data.columns))

    # Plot the stacked bar chart
    crosstab_data.plot(kind='bar', stacked=True, ax=axes[i], color=colors)
    axes[i].set_title(f"{col} vs. RIESGO", fontsize=18)
    axes[i].set_ylabel("Percentage (%)", fontsize=14)
    axes[i].set_xlabel(col, fontsize=14)
    axes[i].tick_params(axis='x', rotation=45, labelsize=10)
    axes[i].tick_params(axis='y', labelsize=14)

# Remove unused subplots
for j in range(len(cat_features), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
fig.suptitle("BARRIO UNION - Porcentaje de Distribución de Riesgo por Variables Categóricas", fontsize=20, y=1.02)
plt.show()

# %% [markdown]
# - Se observan mayores diferencias en los datos de barrios específicos que en los datos globales

# %% [markdown]
# ##### 2.2.2. VARIABLES CONTÍNUAS

# %%
# Observamos correlaciones entre variables numéricas

# Calculamos correlaciones
corr = df[num_features].corr().round(2)

f, ax = plt.subplots(figsize=(12, 4))

# Mascara para ocultar la mitad de la matriz
mask = np.triu(np.ones_like(corr, dtype=bool))
np.fill_diagonal(mask, False)

# Creamos el grafico de correlaciones
sns.heatmap(corr, vmin=-1, vmax=1, annot=True, fmt=".3f", annot_kws={"size": 7}, cmap='BrBG', mask=mask)

plt.title ("Matriz de corelación de Pearson", y=1.1, fontsize=13)
plt.show()

# %% [markdown]
# - Hay alta coorelacion en las variables que miden temperatura y sensación térmica.
# - Se podría mantener solamente TEMPMAX y de esa forma se elimina la multicolinealidad.

# %%
# Valores promedio de variables numéricas por tipo de riesgo
df_num_grop = df.groupby(['RIESGO'])[num_features].mean()
df_num_grop.T
# Out:
# RIESGO                    Alto          Bajo
# TEMPMAX              21.642316     21.093644
# TEMPMIN              13.188089     12.694444
# TEMP                 17.352172     16.830920
# FEELSLIKEMAX         21.837369     21.258723
# FEELSLIKEMIN         12.789878     12.231793
# FEELSLIKE            17.261311     16.700913
# HUMIDITY             74.360688     74.962934
# PRECIP                3.086425      3.704035
# WINDGUST             39.385450     39.915258
# WINDSPEED            23.254691     23.728459
# SEALEVELPRESSURE   1015.582007   1015.719663
# VISIBILITY           10.896062     10.567208
# SEVERERISK            0.980800      0.879614
# TASA_DESEMPLEO        8.181297      8.008080
# POBLACION         20019.939674  21817.550265

# %% [markdown]
# - La principal diferencia es que en promedio cuando hay bajo riesgo de delitos, el volumen de precipitaciones es un poco mayor que cuando el riesgo es alto.
# - Si la poblacion del barrio es menor, hay más frecuencia de alto riesgo

# %%
# Valores promedio de variables numéricas por tipo de riesgo - BARRIO CASAVALLE
df_num_grop = df[df['BARRIO_MONTEVIDEO']== 'CASAVALLE'].groupby(['RIESGO'])[num_features].mean()
df_num_grop.T
# Out:
# RIESGO                    Alto          Bajo
# TEMPMAX              21.858156     20.667911
# TEMPMIN              13.506191     12.184295
# TEMP                 17.618662     16.365439
# FEELSLIKEMAX         22.073204     20.803248
# FEELSLIKEMIN         13.133213     11.669559
# FEELSLIKE            17.537822     16.210276
# HUMIDITY             74.301175     75.248037
# PRECIP                3.205739      3.841266
# WINDGUST             39.364862     40.186108
# WINDSPEED            23.346046     23.795492
# SEALEVELPRESSURE   1015.392228   1015.969365
# VISIBILITY           11.021193     10.323413
# SEVERERISK            1.030276      0.797382
# TASA_DESEMPLEO        8.310334      7.814532
# POBLACION         29851.000000  29851.000000

# %% [markdown]
# - En este barrio hay alguna diferencia más en cuanto al nivel de desempleo

# %%
# Valores promedio de variables numéricas por tipo de riesgo - BARRIO CASAVALLE
df_num_grop = df[df['BARRIO_MONTEVIDEO']== 'CARRASCO'].groupby(['RIESGO'])[num_features].mean()
df_num_grop.T
# Out:
# RIESGO                    Alto          Bajo
# TEMPMAX              22.504591     21.065872
# TEMPMIN              13.658184     12.708954
# TEMP                 18.002096     16.828954
# FEELSLIKEMAX         22.794611     21.212147
# FEELSLIKEMIN         13.276248     12.258789
# FEELSLIKE            17.960579     16.694716
# HUMIDITY             73.745509     74.919339
# PRECIP                3.384716      3.487756
# WINDGUST             39.579461     39.931540
# WINDSPEED            24.465868     23.495817
# SEALEVELPRESSURE   1015.201597   1015.738899
# VISIBILITY           10.525948     10.736734
# SEVERERISK            0.309381      1.031193
# TASA_DESEMPLEO        7.927265      8.088866
# POBLACION         14792.000000  14792.000000

# %% [markdown]
# ##### 2.3 CONCLUSIONES
#
# - El barrio es la variable que tiene más impacto en la variable objetivo
# - Las otras variables categóricas en general no tienen demasiado impacto el la variable objetivo salvo si se observan datos de barrios en específico.
# - Las variables de temperaturas y sensaciones térmicas están altamente correlacionadas, es recomndable conservar solo una por ejemplo Temperatura máxima.
# - Cuando hay bajo riesgo de delitos, el volumen de precipitaciones es un poco mayor que cuando el riesgo es alto.
